# %%
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import time
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence
from collections import Counter
from tqdm import tqdm as tqdm
from itertools import zip_longest
from copy import deepcopy
from collections import Counter
from os.path import join
from codecs import open
from tqdm import tqdm_notebook as tqdm

# %%
def FormatTestFile(file_path,outdata_path):
    trainingset = list()  # store trainingset [content,content,...]
    position = list()  # store position [article_id, start_pos, end_pos, entity_text, entity_type, ...]
    mentions = dict()  # store mentions[mention] = Type
    with open(file_path, 'r', encoding='utf8') as f:
        file_text=f.read().encode('utf-8').decode('utf-8-sig')
    datas=file_text.split('\n\n--------------------\n\n')[:-1]

    output = ""
    for i in tqdm(range(len(datas))):
        data=datas[i].split('\n')
        trainingset=data[1]
        for j in range(len(trainingset)):
            if(trainingset[j] == ' 'or trainingset[j] == '　'):
                output += "_"+" O\n"
            else:
                output += trainingset[j]+" O\n"
            
        output += "\n"
   

    with open(outdata_path, 'w', encoding='utf-8') as f:
        f.write(output)

# %%
def build_corpus(split, make_vocab=True, data_dir="./Data"):
    assert split in ['train', 'dev', 'test']
    word_lists = []
    tag_lists = []
    with open(join(data_dir, split+".char.bmes"), 'r', encoding='utf-8') as f:
        word_list = []
        tag_list = []
        i = 0
        for line in tqdm(f):
            i += 1
            if line != '\r\n' and line != '\n':
                word, tag = line.strip('\r\n').split()
                word_list.append(word)
                tag_list.append(tag)

            else:
                word_lists.append(word_list)
                tag_lists.append(tag_list)
                word_list = []
                tag_list = []

    if make_vocab:
        word2id = build_map(word_lists)
        tag2id = build_map(tag_lists)
        return word_lists, tag_lists, word2id, tag2id
    else:
        return word_lists, tag_lists

# %%
def extend_maps(word2id, tag2id, for_crf=True):
    word2id['<unk>'] = len(word2id)
    word2id['<pad>'] = len(word2id)
    tag2id['<unk>'] = len(tag2id)
    tag2id['<pad>'] = len(tag2id)
    
    if for_crf:
        word2id['<start>'] = len(word2id)
        word2id['<end>'] = len(word2id)
        tag2id['<start>'] = len(tag2id)
        tag2id['<end>'] = len(tag2id)

    return word2id, tag2id

# %%
def prepocess_data_for_lstmcrf(word_lists, tag_lists, test=False):
    assert len(word_lists) == len(tag_lists)
    for i in range(len(word_lists)):
        word_lists[i].append("<end>")
        if not test:  # 如果是测试数据，就不需要加end token了
            tag_lists[i].append("<end>")

    return word_lists, tag_lists

# %%
def cal_lstm_crf_loss(crf_scores, targets, tag2id):

    pad_id = tag2id.get('<pad>')
    start_id = tag2id.get('<start>')
    end_id = tag2id.get('<end>')

    device = crf_scores.device
    batch_size, max_len = targets.size()
    target_size = len(tag2id)

    mask = (targets != pad_id)
    lengths = mask.sum(dim=1)
    targets = indexed(targets, target_size, start_id)

    targets = targets.masked_select(mask) 

    flatten_scores = crf_scores.masked_select(
        mask.view(batch_size, max_len, 1, 1).expand_as(crf_scores)
    ).view(-1, target_size*target_size).contiguous()

    golden_scores = flatten_scores.gather(
        dim=1, index=targets.unsqueeze(1)).sum()

    scores_upto_t = torch.zeros(batch_size, target_size).to(device)
    for t in range(max_len):
        batch_size_t = (lengths > t).sum().item()
        if t == 0:
            scores_upto_t[:batch_size_t] = crf_scores[:batch_size_t,
                                                      t, start_id, :]
        else:
            scores_upto_t[:batch_size_t] = torch.logsumexp(
                crf_scores[:batch_size_t, t, :, :] +
                scores_upto_t[:batch_size_t].unsqueeze(2),
                dim=1
            )
    all_path_scores = scores_upto_t[:, end_id].sum()
    loss = (all_path_scores - golden_scores) / batch_size
    return loss

# %%
def tensorized(batch, maps):
    PAD = maps.get('<pad>')
    UNK = maps.get('<unk>')

    max_len = len(batch[0])
    batch_size = len(batch)

    batch_tensor = torch.ones(batch_size, max_len).long() * PAD
    for i, l in enumerate(batch):
        for j, e in enumerate(l):
            batch_tensor[i][j] = maps.get(e, UNK)
    lengths = [len(l) for l in batch]

    return batch_tensor, lengths

# %%
def sort_by_lengths(word_lists, tag_lists):
    pairs = list(zip(word_lists, tag_lists))
    indices = sorted(range(len(pairs)),
                     key=lambda k: len(pairs[k][0]),
                     reverse=True)
    pairs = [pairs[i] for i in indices]
    word_lists, tag_lists = list(zip(*pairs))
    return word_lists, tag_lists, indices

# %%
def build_map(lists):
    maps = {}
    for list_ in lists:
        for e in list_:
            if e not in maps:
                maps[e] = len(maps)

    return maps

# %%
def load_model(file_name):
    with open(file_name, "rb") as f:
        input_model = pickle.load(f)
    return input_model

# %%
class BILSTM_Model(object):
    def __init__(self, vocab_size, out_size, crf=True):

        self.device = torch.device(
            "cuda" if torch.cuda.is_available() else "cpu")

        self.emb_size = LSTMConfig.emb_size
        self.hidden_size = LSTMConfig.hidden_size

        self.crf = crf

        if not crf:
            self.model = BiLSTM(vocab_size, self.emb_size, self.hidden_size, out_size).to(self.device)
            self.cal_loss_func = cal_loss
        else:
            self.model = BiLSTM_CRF(vocab_size, self.emb_size,self.hidden_size, out_size).to(self.device)
            self.cal_loss_func = cal_lstm_crf_loss

        self.epoches = TrainingConfig.epoches
        self.print_step = TrainingConfig.print_step
        self.lr = TrainingConfig.lr
        self.batch_size = TrainingConfig.batch_size
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.lr)
        self.step = 0
        self._best_val_loss = 1e18
        self.best_model = None
        self.model_temp[100] = None        
        

    def train(self, word_lists, tag_lists,
              dev_word_lists, dev_tag_lists,
              word2id, tag2id):

        word_lists, tag_lists, _ = sort_by_lengths(word_lists, tag_lists)
        dev_word_lists, dev_tag_lists, _ = sort_by_lengths(
            dev_word_lists, dev_tag_lists)

        B = self.batch_size
        for e in (range(1, self.epoches+1)):
            self.step = 0
            losses = 0.
            for ind in tqdm(range(0, len(word_lists), B)):
                batch_sents = word_lists[ind:ind+B]
                batch_tags = tag_lists[ind:ind+B]

                losses += self.train_step(batch_sents,
                                          batch_tags, word2id, tag2id)

                if self.step % TrainingConfig.print_step == 0:
                    total_step = (len(word_lists) // B + 1)

                    losses = 0.

            val_loss = self.validate(dev_word_lists, dev_tag_lists, word2id, tag2id)
            print("Epoch {}/{}, Val Loss:{:.4f}".format(e, self.epoches, val_loss))

    def train_step(self, batch_sents, batch_tags, word2id, tag2id):
        self.model.train()
        self.step += 1

        tensorized_sents, lengths = tensorized(batch_sents, word2id)
        tensorized_sents = tensorized_sents.to(self.device)
        targets, lengths = tensorized(batch_tags, tag2id)
        targets = targets.to(self.device)

        scores = self.model(tensorized_sents, lengths)

        self.optimizer.zero_grad()
        loss = self.cal_loss_func(scores, targets, tag2id).to(self.device)
        loss.backward()
        self.optimizer.step()

        return loss.item()

    def validate(self, dev_word_lists, dev_tag_lists, word2id, tag2id):
        self.model.eval()
        with torch.no_grad():
            val_losses = 0.
            val_step = 0
            for ind in range(0, len(dev_word_lists), self.batch_size):
                val_step += 1

                batch_sents = dev_word_lists[ind:ind+self.batch_size]
                batch_tags = dev_tag_lists[ind:ind+self.batch_size]
                tensorized_sents, lengths = tensorized(
                    batch_sents, word2id)
                tensorized_sents = tensorized_sents.to(self.device)
                targets, lengths = tensorized(batch_tags, tag2id)
                targets = targets.to(self.device)

                scores = self.model(tensorized_sents, lengths)

                loss = self.cal_loss_func(
                    scores, targets, tag2id).to(self.device)
                val_losses += loss.item()
            val_loss = val_losses / val_step

            if val_loss < self._best_val_loss:
                print("Keep the Best...")
                self.best_model = deepcopy(self.model)
                self._best_val_loss = val_loss

            return val_loss

    def test(self, word_lists, tag_lists, word2id, tag2id):
        word_lists, tag_lists, indices = sort_by_lengths(word_lists, tag_lists)
        tensorized_sents, lengths = tensorized(word_lists, word2id)
        tensorized_sents = tensorized_sents.to(self.device)

        self.best_model.eval()
#         self.model.eval()
        with torch.no_grad():
            batch_tagids = self.best_model.test(
                tensorized_sents, lengths, tag2id)

        pred_tag_lists = []
        id2tag = dict((id_, tag) for tag, id_ in tag2id.items())
        for i, ids in enumerate(batch_tagids):
            tag_list = []
            if self.crf:
                for j in range(lengths[i] - 1): 
                    tag_list.append(id2tag[ids[j].item()])
            else:
                for j in range(lengths[i]):
                    tag_list.append(id2tag[ids[j].item()])
            pred_tag_lists.append(tag_list)

        ind_maps = sorted(list(enumerate(indices)), key=lambda e: e[1])
        indices, _ = list(zip(*ind_maps))
        pred_tag_lists = [pred_tag_lists[i] for i in indices]
        tag_lists = [tag_lists[i] for i in indices]

        return pred_tag_lists, tag_lists


class BiLSTM_CRF(nn.Module):
    def __init__(self, vocab_size, emb_size, hidden_size, out_size):

        super(BiLSTM_CRF, self).__init__()
        self.bilstm = BiLSTM(vocab_size, emb_size, hidden_size, out_size)
        self.transition = nn.Parameter(
            torch.ones(out_size, out_size) * 1/out_size)

    def forward(self, sents_tensor, lengths):
        emission = self.bilstm(sents_tensor, lengths)
        batch_size, max_len, out_size = emission.size()
        crf_scores = emission.unsqueeze(
            2).expand(-1, -1, out_size, -1) + self.transition.unsqueeze(0)

        return crf_scores

    def test(self, test_sents_tensor, lengths, tag2id):
        start_id = tag2id['<start>']
        end_id = tag2id['<end>']
        pad = tag2id['<pad>']
        tagset_size = len(tag2id)

        crf_scores = self.forward(test_sents_tensor, lengths)
        device = crf_scores.device
        B, L, T, _ = crf_scores.size()
        viterbi = torch.zeros(B, L, T).to(device)
        backpointer = (torch.zeros(B, L, T).long() * end_id).to(device)
        lengths = torch.LongTensor(lengths).to(device)
        for step in range(L):
            batch_size_t = (lengths > step).sum().item()
            if step == 0:
                viterbi[:batch_size_t, step,
                        :] = crf_scores[: batch_size_t, step, start_id, :]
                backpointer[: batch_size_t, step, :] = start_id
            else:
                max_scores, prev_tags = torch.max(
                    viterbi[:batch_size_t, step-1, :].unsqueeze(2) +
                    crf_scores[:batch_size_t, step, :, :],  
                    dim=1
                )
                viterbi[:batch_size_t, step, :] = max_scores
                backpointer[:batch_size_t, step, :] = prev_tags

        backpointer = backpointer.view(B, -1)
        tagids = [] 
        tags_t = None
        for step in range(L-1, 0, -1):
            batch_size_t = (lengths > step).sum().item()
            if step == L-1:
                index = torch.ones(batch_size_t).long() * (step * tagset_size)
                index = index.to(device)
                index += end_id
            else:
                prev_batch_size_t = len(tags_t)

                new_in_batch = torch.LongTensor(
                    [end_id] * (batch_size_t - prev_batch_size_t)).to(device)
                offset = torch.cat(
                    [tags_t, new_in_batch],
                    dim=0
                ) 
                index = torch.ones(batch_size_t).long() * (step * tagset_size)
                index = index.to(device)
                index += offset.long()

            try:
                tags_t = backpointer[:batch_size_t].gather(
                    dim=1, index=index.unsqueeze(1).long())
            except RuntimeError:
                import pdb
                pdb.set_trace()
            tags_t = tags_t.squeeze(1)
            tagids.append(tags_t.tolist())

        tagids = list(zip_longest(*reversed(tagids), fillvalue=pad))
        tagids = torch.Tensor(tagids).long()

        return tagids

# %%
class BiLSTM(nn.Module):
    def __init__(self, vocab_size, emb_size, hidden_size, out_size):

        super(BiLSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, emb_size)
        self.bilstm = nn.LSTM(emb_size, hidden_size,
                              batch_first=True,
                              bidirectional=True)

        self.lin = nn.Linear(2*hidden_size, out_size)

    def forward(self, sents_tensor, lengths):
        emb = self.embedding(sents_tensor)  # [B, L, emb_size]

        packed = pack_padded_sequence(emb, lengths, batch_first=True)
        rnn_out, _ = self.bilstm(packed)
        rnn_out, _ = pad_packed_sequence(rnn_out, batch_first=True)

        scores = self.lin(rnn_out)  # [B, L, out_size]

        return scores

    def test(self, sents_tensor, lengths, _):
        logits = self.forward(sents_tensor, lengths)  # [B, L, out_size]
        _, batch_tagids = torch.max(logits, dim=2)

        return batch_tagids

# %%
# inputdata_path = f"test.txt"       #要轉換的檔案
# outdata_path = f'./Data/test.char.bmes'   #轉換輸出的檔案

# FormatTestFile(inputdata_path,outdata_path)

# %%
word2id = {'醫': 0, '師': 1, '：': 2, '啊': 3, '回': 4, '去': 5, '還': 6, '好': 7, '嗎': 8, '？': 9, '民': 10, '眾': 11, '欸': 12, '，': 13, '是': 14, '虛': 15, '的': 16, '但': 17, '。': 18, '真': 19, '險': 20, '坦': 21, '白': 22, '講': 23, '我': 24, '剛': 25, '時': 26, '候': 27, '晚': 28, '上': 29, '有': 30, '盜': 31, '汗': 32, '阿': 33, '只': 34, '前': 35, '天': 36, '很': 37, '多': 38, '就': 39, '算': 40, '沒': 41, '可': 42, '一': 43, '覺': 44, '到': 45, '明': 46, '
crf_word2id, crf_tag2id = extend_maps(word2id, tag2id, for_crf=True)
bilstm_model = load_model(BiLSTMCRF_MODEL_PATH)
bilstm_model.model.bilstm.bilstm.flatten_parameters()  # remove warning
test_word_lists, test_tag_lists = prepocess_data_for_lstmcrf(test_word_lists, test_tag_lists, test=True)
lstmcrf_pred, target_tag_list = bilstm_model.test(test_word_lists, test_tag_lists, crf_word2id, crf_tag2id)

print("article_id\tstart_position\tend_position\tentity_text\tentity_type")
output = ""
start = ""
end = ""
tag = ""
line = ""
output += "article_id\tstart_position\tend_position\tentity_text\tentity_type\n"
flag = 0
for chap in range(len(test_word_lists)):
    for text in range(len(test_word_lists[chap][:-1])):
        if lstmcrf_pred[chap][text][0] == 'B':            
            if line != "":
                end = text
                if end-start == len(line):
                    output += "{:}\t{:}\t{:}\t{:}\t{:}\n".format(chap, start, end, line, tag)
                    print("{:}\t{:}\t{:}\t{:}\t{:}".format(chap, start, end, line, tag))
                flag = 0
            start = text            
            tag = lstmcrf_pred[chap][text][2:]
            line = ""
            line += str(test_word_lists[chap][text])
            flag = 1
        elif lstmcrf_pred[chap][text][0] == 'I':
            if flag == 0:
                start = text
                tag = lstmcrf_pred[chap][text][2:]
                flag = 1
            line += str(test_word_lists[chap][text])
        elif lstmcrf_pred[chap][text][0] == 'O':
            if line != "":
                end = text
                if end-start == len(line):
                    output += "{:}\t{:}\t{:}\t{:}\t{:}\n".format(chap, start, end, line, tag)
                    print("{:}\t{:}\t{:}\t{:}\t{:}".format(chap, start, end, line, tag))
                line = ""
                flag = 0
output_path = 'output.tsv'
with open(output_path, 'w', encoding='utf-8') as f:
    f.write(output)
# Out:
# Load File...
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Testing...
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/rnn.py:585: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at  ../aten/src/ATen/native/cudnn/RNN.cpp:775.)
#   self.num_layers, self.dropout, self.training, self.bidirectional)
# article_id	start_position	end_position	entity_text	entity_type
# 0	198	200	新樓	location
# 0	227	229	麻豆	location
# 0	237	239	麻豆	location
# 0	295	297	今年	time
# 1	31	33	今天	time
# 1	40	42	昨天	time
# 1	76	80	0.79	med_exam
# 1	94	96	88	med_exam
# 1	179	181	20	time
# 1	182	184	19	time
# 1	258	261	2.6	med_exam
# 1	360	363	黃醫師	name
# 1	366	369	6.6	med_exam
# 1	385	388	6.6	med_exam
# 1	394	397	8.3	med_exam
# 1	407	410	8.3	med_exam
# 1	414	421	四個月前8.3	time
# 1	463	466	6.2	med_exam
# 1	469	472	三個月	time
# 1	626	629	黃醫師	name
# 1	670	673	格里曼	location
# 1	721	723	里曼	location
# 1	742	744	中午	time
# 1	755	757	里曼	location
# 1	867	869	21	time
# 1	873	875	21	time
# 1	881	884	12天	time
# 1	890	893	12天	time
# 1	902	906	三個星期	time
# 2	170	174	1100	med_exam
# 2	245	249	1145	med_exam
# 2	275	278	500	money
# 2	285	288	500	money
# 2	390	393	三個月	time
# 2	402	405	三個月	time
# 2	681	683	57	med_exam
# 2	699	701	52	med_exam
# 2	792	795	兩個月	time
# 2	1090	1094	7.56	med_exam
# 2	1151	1155	450塊	money
# 2	1239	1241	35	med_exam
# 2	1246	1248	35	med_exam
# 2	1394	1398	450塊	money
# 3	6	8	昨天	time
# 3	11	13	一天	time
# 3	45	47	早上	time
# 3	221	223	昨天	time
# 3	225	227	早上	time
# 3	263	267	今天早上	time
# 3	538	540	前天	time
# 3	543	545	一天	time
# 3	568	570	一天	time
# 3	643	645	昨天	time
# 3	662	664	昨天	time
# 3	673	675	今天	time
# 3	678	681	吳醫師	name
# 3	748	750	今天	time
# 3	867	870	禮拜二	time
# 3	871	874	禮拜三	time
# 4	6	8	嘉明	location
# 4	24	26	今年	time
# 4	45	47	今天	time
# 4	148	152	36．9	med_exam
# 4	157	162	36．9度	med_exam
# 4	163	168	36．9度	med_exam
# 4	173	176	114	med_exam
# 4	177	179	66	med_exam
# 4	187	192	8月13號	time
# 4	215	218	622	med_exam
# 4	288	290	15	med_exam
# 4	319	321	15	med_exam
# 4	326	328	31	med_exam
# 4	365	368	三個禮	time
# 4	369	372	三個月	time
# 4	426	428	半年	time
# 4	436	438	半年	time
# 4	495	498	31歲	med_exam
# 5	53	55	四月	time
# 5	106	108	20	med_exam
# 5	114	116	20	med_exam
# 5	151	155	9700	med_exam
# 5	162	166	9700	money
# 5	171	175	9700	time
# 5	184	186	榮總	location
# 5	188	193	10600	med_exam
# 5	206	211	10600	time
# 5	219	222	600	money
# 5	232	236	9700	money
# 5	699	704	9000幾	time
# 5	726	732	10月25號	time
# 5	1010	1013	兩個月	time
# 5	1035	1038	兩個月	time
# 5	1051	1057	10月25號	time
# 5	1139	1143	10月底	time
# 5	1148	1152	11月初	time
# 5	1167	1169	兩個	time
# 5	1170	1173	兩個月	time
# 5	1235	1238	劉醫師	name
# 5	1288	1291	兩個月	time
# 5	1303	1306	兩個月	time
# 5	1324	1327	一個月	time
# 5	1345	1348	兩個月	time
# 5	1357	1360	一個月	time
# 5	1372	1375	兩個月	time
# 5	1383	1386	14號	time
# 5	1395	1400	今天14號	time
# 5	1413	1419	10月14號	time
# 5	1434	1437	25號	time
# 5	1451	1457	10月25號	time
# 5	1466	1472	10月25號	time
# 5	1478	1484	10月25號	time
# 5	1490	1493	下個月	time
# 5	1499	1504	9月24號	time
# 5	1509	1515	10月25號	time
# 5	1527	1530	兩個月	time
# 5	1556	1559	兩個月	time
# 5	1563	1566	兩個月	time
# 5	1570	1573	兩個月	time
# 5	1587	1591	七個禮拜	time
# 5	1630	1633	25號	time
# 5	2105	2108	一個月	time
# 5	2223	2227	9700	time
# 5	2241	2245	9700	med_exam
# 5	2268	2270	20	med_exam
# 5	2271	2273	20	time
# 5	2275	2277	20	money
# 5	2309	2315	90、100	time
# 6	106	112	二點一二公分	med_exam
# 6	155	161	七月三十一號	time
# 6	164	170	七月三十一號	time
# 6	194	196	九月	time
# 6	317	322	四點多公分	time
# 6	406	410	三、四週	time
# 6	414	419	這三、四週	time
# 6	521	524	前兩週	time
# 6	758	760	下週	time
# 6	786	788	九月	time
# 6	803	807	一個禮拜	time
# 6	810	813	兩個月	time
# 6	1044	1046	早上	time
# 6	1191	1194	鞏醫師	name
# 6	1241	1245	四個禮拜	time
# 6	1328	1332	一個禮拜	time
# 6	1375	1379	兩個禮拜	time
# 6	1380	1383	兩個月	time
# 6	1468	1471	兩個月	time
# 6	1584	1587	連醫師	name
# 6	1814	1818	四個禮拜	time
# 6	1839	1841	今天	time
# 6	1888	1890	今天	time
# 6	1971	1973	今年	time
# 6	2261	2264	三五八	time
# 7	41	43	學姊	name
# 7	63	66	這幾天	time
# 7	76	81	兩、三點半	time
# 7	717	722	一、兩個月	time
# 7	726	731	一、兩個月	time
# 7	749	751	一年	time
# 7	812	814	8月	time
# 7	831	834	4個月	time
# 7	945	948	禮拜二	time
# 7	964	966	一月	time
# 7	967	969	二月	time
# 7	973	977	明年三月	time
# 7	982	986	明年三月	time
# 7	989	993	明年三月	time
# 7	1001	1005	明年三月	time
# 7	1013	1016	禮拜二	time
# 7	1021	1024	禮拜二	time
# 7	1033	1035	三月	time
# 7	1047	1052	上個禮拜三	time
# 7	1087	1089	媽媽	family
# 7	1113	1117	3月2號	time
# 7	1128	1132	800塊	money
# 7	1136	1140	800塊	money
# 8	39	44	九百一十三	med_exam
# 8	60	62	五百	med_exam
# 8	124	127	四十一	med_exam
# 8	129	131	十九	med_exam
# 8	196	198	今天	time
# 8	216	218	台大	location
# 8	504	507	五千五	money
# 8	525	528	五千五	money
# 8	543	547	一萬五千	money
# 8	553	557	一萬五千	money
# 8	633	636	一個月	time
# 8	641	645	第六個月	time
# 8	672	675	兩個月	time
# 8	686	689	四個月	time
# 8	882	885	三百塊	money
# 8	943	947	四個禮拜	time
# 8	1052	1055	十二月	time
# 8	1058	1063	二月十五號	time
# 8	1153	1158	56387	med_exam
# 9	3	6	林大華	name
# 9	7	17	E127388873	time
# 9	74	77	林醫師	name
# 9	861	863	媽媽	family
# 9	1221	1223	4月	time
# 9	1384	1386	四月	time
# 9	1453	1459	14幾15幾	med_exam
# 9	1525	1528	140	med_exam
# 9	1599	1602	120	money
# 9	1603	1605	80	money
# 9	2721	2724	三個月	time
# 9	2763	2766	一個月	time
# 9	2807	2809	早上	time
# 9	2913	2917	13.7	med_exam
# 10	8	11	李醫師	name
# 10	43	47	上個禮拜	time
# 10	129	132	這禮拜	time
# 10	281	283	GL	contact
# 10	683	687	100塊	money
# 10	694	698	100塊	money
# 10	1087	1089	那天	time
# 10	1269	1272	禮拜六	time
# 10	1278	1281	禮拜一	time
# 10	1298	1301	禮拜四	time
# 10	1311	1314	禮拜四	time
# 10	1319	1322	禮拜六	time
# 10	1470	1472	台灣	location
# 11	4	8	這個禮拜	time
# 11	125	127	晚上	time
# 11	165	170	Googl	profession
# 11	872	876	17.1	med_exam
# 11	885	888	上禮拜	time
# 11	932	935	121	med_exam
# 11	940	942	29	med_exam
# 11	944	948	上個禮拜	time
# 11	951	953	17	med_exam
# 11	963	965	17	med_exam
# 11	1161	1164	許醫師	name
# 11	1177	1181	上個禮拜	time
# 11	1218	1221	120	time
# 11	1318	1322	八個小時	time
# 11	1353	1356	120	time
# 11	1425	1427	爺爺	family
# 11	1498	1502	上個禮拜	time
# 11	1632	1634	爸爸	family
# 11	1735	1736	A	clinical_event
# 11	1755	1759	2540	med_exam
# 11	2527	2531	這個禮拜	time
# 11	2936	2940	兩三年前	time
# 11	3416	3418	半年	time
# 11	3434	3438	2540	med_exam
# 11	3549	3552	201	time
# 11	3579	3584	2013年	time
# 11	4438	4440	四年	time
# 11	4485	4489	2013	time
# 11	4496	4501	2013年	time
# 11	4562	4563	許	name
# 11	4563	4567	王玉醫師	name
# 11	4919	4924	台南國小當	location
# 11	4930	4932	昨天	time
# 11	5040	5043	下禮拜	time
# 11	5048	5051	下禮拜	time
# 11	5067	5070	下禮拜	time
# 11	5085	5087	早上	time
# 11	5091	5094	禮拜五	time
# 11	5095	5097	早上	time
# 11	5104	5107	禮拜五	time
# 11	5108	5110	早上	time
# 11	5124	5127	許醫師	name
# 11	5180	5186	11月30號	time
# 11	5191	5196	11/29	time
# 11	5210	5215	11/29	time
# 11	5618	5621	八公斤	med_exam
# 11	5697	5699	75	med_exam
# 11	5704	5706	63	med_exam
# 11	5707	5709	62	med_exam
# 11	5727	5730	十公斤	med_exam
# 11	5774	5776	63	med_exam
# 11	5787	5789	75	med_exam
# 11	5790	5794	63公斤	med_exam
# 11	5809	5814	8月23日	time
# 11	5824	5827	一個月	time
# 11	5859	5864	上個禮拜五	time
# 11	6171	6174	徐醫師	name
# 11	6215	6217	今天	time
# 12	169	171	今天	time
# 12	276	280	下個禮拜	time
# 13	160	162	前年	time
# 13	178	180	前年	time
# 13	188	190	今年	time
# 13	192	195	九月份	time
# 13	217	219	今年	time
# 13	366	369	六零九	med_exam
# 13	504	506	今年	time
# 13	517	519	一年	time
# 13	965	968	一七五	med_exam
# 13	973	976	七十三	med_exam
# 13	980	983	一七五	med_exam
# 13	984	987	七十三	med_exam
# 13	1025	1028	七十八	med_exam
# 13	1110	1112	十四	time
# 13	1149	1152	一二五	med_exam
# 13	1153	1156	七十五	med_exam
# 13	1165	1168	一二五	med_exam
# 13	1169	1172	七十五	med_exam
# 13	1276	1283	7354975	contact
# 14	269	271	去年	time
# 14	529	532	349	med_exam
# 14	605	609	晚上睡前	time
# 14	693	695	明年	time
# 14	741	743	半年	time
# 14	900	903	三百塊	money
# 14	930	932	今天	time
# 14	1011	1013	台大	location
# 14	1258	1263	78362	med_exam
# 15	3	8	這兩個禮拜	time
# 15	58	61	李醫師	name
# 15	67	70	李醫師	name
# 15	81	84	李醫師	name
# 15	194	197	11月	time
# 15	221	225	下個禮拜	time
# 15	302	306	兩個禮拜	time
# 15	310	314	兩個禮拜	time
# 15	315	319	兩個禮拜	time
# 15	620	626	11月20號	time
# 15	648	650	47	med_exam
# 15	651	653	42	med_exam
# 15	666	669	0.2	med_exam
# 15	708	712	兩個禮拜	time
# 16	141	145	62公斤	med_exam
# 16	149	151	62	med_exam
# 16	163	168	173公分	med_exam
# 16	172	177	173公分	med_exam
# 16	266	269	263	med_exam
# 16	290	292	20	med_exam
# 16	405	409	200多	money
# 16	472	475	三個月	time
# 16	594	599	今年的年底	time
# 16	623	627	2月2號	time
# 16	649	652	三個月	time
# 16	663	666	一年4	time
# 16	703	705	1年	time
# 16	785	788	3個月	time
# 16	794	798	1500	money
# 16	832	837	2月16號	time
# 17	328	332	四個禮拜	time
# 17	392	396	0.83	med_exam
# 17	408	410	87	med_exam
# 17	600	603	6.7	med_exam
# 17	608	611	6.7	med_exam
# 17	625	628	三個月	time
# 17	710	714	9/15	time
# 17	716	720	四個禮拜	time
# 18	487	491	五月月份	time
# 18	501	504	四個月	time
# 18	591	594	五月份	time
# 18	608	611	九月份	time
# 18	615	618	四個月	time
# 18	632	635	兩個月	time
# 18	674	676	今天	time
# 18	734	736	昨天	time
# 18	737	739	晚上	time
# 18	807	809	今天	time
# 18	907	909	早上	time
# 18	916	918	下午	time
# 18	924	926	下午	time
# 18	928	931	禮拜三	time
# 18	940	943	禮拜三	time
# 18	944	946	下午	time
# 18	963	965	下午	time
# 18	1011	1014	六十八	med_exam
# 18	1020	1023	六十八	med_exam
# 18	1144	1147	禮拜三	time
# 18	1149	1154	下個禮拜三	time
# 18	1166	1168	下午	time
# 18	1194	1196	下午	time
# 18	1216	1219	上早上	time
# 18	1232	1234	下午	time
# 18	1251	1255	下禮拜三	time
# 18	1295	1297	今天	time
# 18	1299	1301	早上	time
# 18	1507	1509	七天	time
# 18	1531	1534	禮拜三	time
# 18	1543	1544	塊	money
# 18	1545	1547	三天	time
# 18	1767	1769	哥哥	family
# 18	1793	1795	哥哥	family
# 18	1836	1839	625	med_exam
# 19	21	24	禮拜五	time
# 19	32	35	禮拜六	time
# 19	56	58	三天	time
# 19	341	344	這禮拜	time
# 19	505	508	禮拜五	time
# 19	540	542	今天	time
# 19	795	798	禮拜一	time
# 19	804	806	晚上	time
# 19	829	832	禮拜三	time
# 19	927	929	今天	time
# 19	996	999	禮拜天	time
# 19	1000	1002	早上	time
# 19	1413	1416	禮拜二	time
# 19	1432	1436	這禮拜二	time
# 19	1446	1450	下禮拜一	time
# 19	1464	1468	下禮拜一	time
# 19	1475	1479	下禮拜一	time
# 19	1487	1491	下禮拜一	time
# 19	1499	1503	一個禮拜	time
# 19	1531	1533	兩天	time
# 19	1557	1559	兩天	time
# 19	1609	1611	一天	time
# 19	1700	1703	禮拜天	time
# 20	131	135	下下禮拜	time
# 20	137	141	下下禮拜	time
# 20	143	145	台中	location
# 20	194	197	禮拜四	time
# 20	198	203	這個禮拜四	time
# 20	209	212	禮拜四	time
# 20	217	222	這個禮拜四	time
# 20	277	280	星期四	time
# 20	286	290	這禮拜四	time
# 20	316	321	下下個禮拜	time
# 20	329	332	禮拜一	time
# 20	336	339	禮拜一	time
# 20	355	357	禮拜	time
# 20	359	362	禮拜四	time
# 20	378	380	禮拜	time
# 20	382	385	禮拜幾	time
# 20	391	395	這禮拜四	time
# 20	1028	1031	禮拜三	time
# 20	1041	1044	禮拜三	time
# 20	1050	1052	兩天	time
# 20	1126	1129	禮拜四	time
# 20	1148	1151	禮拜四	time
# 20	1171	1173	禮拜	time
# 20	1175	1177	禮拜	time
# 20	1286	1289	中山路	location
# 20	1298	1301	中山路	location
# 21	25	29	72公斤	med_exam
# 21	77	81	1107	med_exam
# 21	86	90	1107	med_exam
# 21	99	105	1106.5	med_exam
# 21	106	109	四捨五	med_exam
# 21	110	114	1107	med_exam
# 21	132	136	1107	med_exam
# 21	137	141	6/14	med_exam
# 21	198	200	89	med_exam
# 21	212	215	4.8	med_exam
# 21	216	219	4.8	med_exam
# 21	294	296	今年	time
# 21	908	911	這半年	time
# 22	65	69	三個禮拜	time
# 22	164	166	63	med_exam
# 22	311	316	前兩個禮拜	time
# 22	602	604	半年	time
# 22	752	756	7382	ID
# 23	897	900	胡蘭竹	location
# 23	1166	1170	215塊	money
# 23	1389	1392	170	med_exam
# 23	1393	1396	180	med_exam
# 23	1400	1403	170	med_exam
# 23	1404	1407	180	med_exam
# 23	1537	1539	晚上	time
# 23	1541	1543	五點	time
# 23	1639	1642	180	med_exam
# 23	1662	1665	170	med_exam
# 23	1666	1669	180	time
# 23	1906	1909	六月份	time
# 23	1986	1989	六月份	time
# 23	2078	2080	一天	time
# 23	2152	2155	120	time
# 23	2156	2159	130	med_exam
# 24	37	39	兩個	time
# 24	40	44	兩個禮拜	time
# 24	137	139	59	med_exam
# 24	143	145	59	med_exam
# 24	194	198	2個小時	time
# 24	297	301	兩個禮拜	time
# 24	325	327	早上	time
# 24	328	330	下午	time
# 24	339	341	早上	time
# 24	372	377	12月15	time
# 24	381	384	禮拜一	time
# 24	457	459	早上	time
# 24	475	477	早上	time
# 25	37	39	兩天	time
# 25	47	49	兩天	time
# 25	164	166	晚上	time
# 25	194	197	一個月	time
# 25	278	281	禮拜四	time
# 25	282	284	早上	time
# 25	647	651	高雄大學	location
# 25	653	655	律系	education
# 25	676	678	五年	time
# 26	157	159	55	med_exam
# 26	163	165	55	med_exam
# 26	176	179	162	med_exam
# 26	183	186	162	med_exam
# 26	358	360	一天	time
# 26	454	457	497	med_exam
# 26	466	469	497	med_exam
# 26	541	545	700多	time
# 26	584	588	6個小時	time
# 26	637	640	半年前	time
# 26	642	644	30	med_exam
# 26	1030	1033	李醫師	name
# 26	1123	1126	140	med_exam
# 26	1422	1424	晚上	time
# 26	1584	1586	半年	time
# 27	276	281	0．125	time
# 27	288	294	10ＭＩＮＩ	time
# 27	1016	1019	禮拜四	time
# 27	1025	1028	禮拜三	time
# 27	1029	1032	禮拜四	time
# 27	1039	1044	三個禮拜後	time
# 27	1045	1048	禮拜四	time
# 27	1053	1059	10月12號	time
# 28	89	94	九一二點四	med_exam
# 28	97	100	九一二	med_exam
# 28	146	148	四十	med_exam
# 28	149	151	四十	med_exam
# 28	276	279	九點一	time
# 28	315	316	八	med_exam
# 28	337	340	九點一	time
# 28	483	485	半年	time
# 28	559	562	八十九	med_exam
# 28	604	607	七十一	med_exam
# 28	1096	1098	今年	time
# 28	1099	1101	今年	time
# 28	1175	1179	六十五歲	time
# 28	1451	1455	一年四次	time
# 28	1577	1579	半年	time
# 28	1580	1582	一年	time
# 28	1586	1588	一年	time
# 28	1590	1592	一年	time
# 28	1596	1598	今年	time
# 28	1620	1623	今年初	time
# 28	1627	1629	今年	time
# 28	1639	1642	明年初	time
# 28	1663	1665	七月	time
# 28	1672	1674	七月	time
# 28	1682	1684	七月	time
# 28	1814	1816	半年	time
# 29	27	31	0．42	med_exam
# 29	32	35	90分	time
# 29	42	44	12	med_exam
# 29	49	52	2．1	med_exam
# 29	56	59	2．1	med_exam
# 29	338	340	今年	time
# 29	587	590	3個月	time
# 29	626	629	一個月	time
# 29	655	658	三個月	time
# 29	807	810	三個月	time
# 29	859	861	蘆洲	location
# 30	4	6	小明	name
# 30	22	27	7月19號	time
# 30	36	39	935	med_exam
# 30	171	174	2月初	time
# 30	192	196	7月19	time
# 30	465	467	半年	time
# 30	527	529	今年	time
# 30	540	544	長庚醫院	location
# 30	661	663	今年	time
# 30	809	812	苓雅區	location
# 30	862	865	苓雅區	location
# 30	868	870	高雄	location
# 30	878	880	高雄	location
# 30	885	888	苓雅區	location
# 30	920	922	8月	time
# 30	923	925	8月	time
# 30	966	968	8月	time
# 30	1013	1016	11月	time
# 30	1036	1038	2月	time
# 30	1039	1043	2月下半	time
# 30	1046	1048	明年	time
# 30	1049	1053	2月下半	time
# 30	1055	1058	下半月	time
# 30	1100	1102	半年	time
# 30	1213	1218	2月25號	time
# 31	269	272	劉醫師	name
# 31	317	320	劉醫師	name
# 31	864	866	中午	time
# 31	981	985	三、四天	time
# 31	1093	1096	劉醫師	name
# 31	1324	1328	六、七成	time
# 31	1375	1377	三個	time
# 31	1378	1381	三個月	time
# 31	1444	1447	三個月	time
# 31	1628	1631	劉醫師	name
# 31	1868	1870	年底	time
# 31	1883	1886	十一月	time
# 32	78	81	林醫師	name
# 32	86	89	林醫師	name
# 32	149	153	9.53	med_exam
# 32	158	162	9.53	med_exam
# 32	164	166	今天	time
# 32	235	239	上上禮拜	time
# 32	243	247	上上禮拜	time
# 32	269	272	林醫師	name
# 32	737	740	兩個月	time
# 32	743	746	兩個月	time
# 32	767	771	四個禮拜	time
# 32	778	782	黃大醫師	name
# 32	847	851	四個禮拜	time
# 32	858	862	四個禮拜	time
# 32	913	917	四個禮拜	time
# 32	927	931	四個禮拜	time
# 32	937	941	黃大醫師	name
# 32	1001	1005	黃大醫師	name
# 32	1034	1035	林	name
# 32	1037	1040	林醫師	name
# 33	15	18	這個月	time
# 33	161	164	690	med_exam
# 33	224	227	明年初	time
# 33	314	316	今年	time
# 33	390	392	一年	time
# 33	400	403	今年初	time
# 33	416	418	今年	time
# 33	428	430	去年	time
# 33	441	444	去年初	time
# 33	446	450	今年年底	time
# 33	457	461	去年年底	time
# 33	462	466	今年年初	time
# 33	524	526	去年	time
# 33	528	533	2月25號	time
# 33	553	558	2月25號	time
# 33	630	632	今年	time
# 33	680	683	3個月	time
# 34	3	5	今年	time
# 34	6	8	今年	time
# 34	26	28	今年	time
# 34	302	305	八月多	time
# 34	311	314	874	med_exam
# 34	315	320	8月20號	time
# 34	332	334	八月	time
# 34	339	341	半年	time
# 34	379	381	八月	time
# 34	382	384	八月	time
# 34	385	387	九月	time
# 34	396	398	八月	time
# 34	399	401	九月	time
# 34	444	447	901	time
# 34	451	453	九月	time
# 34	454	456	十月	time
# 34	457	460	十一月	time
# 34	465	467	九月	time
# 34	538	541	二月底	time
# 34	543	548	二月二十五	time
# 34	552	557	二月二十五	time
# 34	567	570	十二週	time
# 35	621	625	三個禮拜	time
# 35	693	696	兩個月	time
# 35	773	775	晚上	time
# 35	1109	1111	早上	time
# 35	1122	1124	早上	time
# 35	1250	1253	三個月	time
# 35	1393	1397	兩個禮拜	time
# 35	1643	1645	兩天	time
# 35	1802	1811	103846354	time
# 36	14	18	1358	med_exam
# 36	39	42	256	med_exam
# 36	59	62	200	money
# 36	99	102	195	med_exam
# 36	121	124	130	med_exam
# 36	192	194	早上	time
# 36	243	244	爸	family
# 36	490	492	半年	time
# 36	496	498	半年	time
# 36	589	592	五十歲	time
# 36	708	714	第二批政府公	time
# 36	957	960	172	med_exam
# 36	965	967	59	med_exam
# 36	968	970	60	med_exam
# 36	974	976	59	med_exam
# 36	977	979	60	med_exam
# 36	1115	1125	E183745524	time
# 37	82	85	130	med_exam
# 37	89	92	130	med_exam
# 37	187	191	一個禮拜	time
# 37	289	291	今年	time
# 37	328	331	黃醫師	name
# 37	404	406	明年	time
# 38	12	14	早上	time
# 38	300	303	林醫師	name
# 38	305	308	林醫師	name
# 38	655	657	禮拜	time
# 38	662	666	一個禮拜	time
# 38	674	677	禮拜三	time
# 38	691	696	下下禮拜三	time
# 38	727	731	下個禮拜	time
# 38	771	776	42234	time
# 39	54	56	李延	name
# 39	252	255	李醫師	name
# 39	417	421	上星期二	time
# 39	423	427	上星期二	time
# 39	565	568	星期二	time
# 39	799	802	三個月	time
# 39	814	817	三個月	time
# 39	871	874	李醫師	name
# 39	1036	1040	上禮拜五	time
# 39	1407	1409	九歲	time
# 39	1411	1412	媽	family
# 39	1421	1423	爸爸	family
# 39	1486	1490	8353	ID
# 40	226	228	今天	time
# 40	236	238	今天	time
# 40	500	509	184666204	time
# 41	359	363	二十八歲	time
# 41	579	584	五百九十三	med_exam
# 41	585	590	五百九十三	med_exam
# 41	600	605	五八六點七	time
# 41	607	609	二月	time
# 41	618	620	四百	med_exam
# 41	649	651	五百	time
# 41	666	668	五百	med_exam
# 41	806	809	一千六	money
# 41	824	827	一千六	money
# 41	834	837	一千六	money
# 41	936	941	二零一六年	time
# 41	942	948	十一月十八號	time
# 41	1073	1075	台灣	location
# 41	1363	1366	這一批	time
# 41	1524	1526	一千	money
# 41	1527	1530	一千七	money
# 41	2067	2073	九月二十三號	time
# 41	2099	2105	明年的二月底	time
# 41	2120	2122	半年	time
# 41	2593	2595	台東	location
# 41	2680	2682	台東	location
# 42	5	13	63554吳秀妹	ID
# 42	42	44	晚上	time
# 42	96	98	晚上	time
# 42	108	111	10幾	med_exam
# 42	235	237	晚上	time
# 42	741	744	5分鐘	time
# 42	750	753	5分鐘	time
# 42	1101	1103	晚上	time
# 42	1135	1137	白天	time
# 42	1301	1304	大學路	location
# 42	1347	1351	一個禮拜	time
# 42	1375	1377	今年	time
# 43	169	171	一年	time
# 43	193	196	632	med_exam
# 43	200	203	632	med_exam
# 43	248	251	500	med_exam
# 43	611	616	李家明醫師	name
# 43	633	635	明年	time
# 43	636	638	7月	time
# 43	659	661	半年	time
# 43	677	680	李家明	name
# 43	827	830	區公所	location
# 43	895	897	5年	time
# 43	911	914	李醫師	name
# 43	967	972	星星幼兒園	time
# 43	1005	1007	1月	time
# 43	1018	1021	半年前	time
# 44	10	16	566480	med_exam
# 44	286	290	400多	med_exam
# 44	301	305	400多	money
# 44	353	356	200	med_exam
# 44	358	361	200	time
# 44	369	372	455	med_exam
# 44	384	385	2	time
# 44	387	390	221	time
# 44	391	394	222	time
# 44	494	497	7.5	med_exam
# 44	531	533	98	med_exam
# 44	540	542	98	med_exam
# 44	1029	1031	F2	time
# 45	38	40	昨天	time
# 45	54	58	2750	med_exam
# 45	96	98	10	med_exam
# 45	409	412	兩個月	time
# 45	419	422	禮拜三	time
# 45	447	450	禮拜三	time
# 45	1032	1034	台中	location
# 45	1419	1424	這一兩個月	time
# 45	1451	1454	0.5	med_exam
# 45	1507	1511	67.5	med_exam
# 45	1574	1576	昨天	time
# 45	1594	1597	三公斤	time
# 45	1604	1607	0.5	med_exam
# 45	1613	1616	四公斤	med_exam
# 45	1723	1726	0.5	med_exam
# 45	1737	1742	兩個禮拜前	time
# 45	1745	1748	0.5	med_exam
# 45	1773	1775	63	med_exam
# 45	1789	1791	63	med_exam
# 45	1800	1802	昨天	time
# 45	1808	1812	67.5	med_exam
# 45	1823	1827	67.5	med_exam
# 45	1833	1835	68	med_exam
# 45	2075	2080	62、63	time
# 45	2099	2101	61	med_exam
# 45	2105	2107	61	time
# 45	2119	2122	這半年	time
# 45	2223	2228	這一兩個月	time
# 45	2250	2254	這兩個月	time
# 45	2261	2265	一兩公斤	time
# 45	2292	2296	長庚醫院	location
# 45	2330	2333	12月	time
# 45	2337	2343	10月13號	time
# 45	2344	2349	11月17	time
# 45	2353	2356	兩個月	time
# 45	2359	2362	下個月	time
# 45	2456	2458	長庚	location
# 45	2795	2797	台大	location
# 45	2844	2848	長庚醫院	location
# 45	2903	2905	早上	time
# 45	2906	2908	下午	time
# 45	3010	3013	三個月	time
# 45	3020	3023	三個月	time
# 45	3210	3213	1/3	time
# 45	3217	3220	7/3	time
# 45	3224	3227	1/3	time
# 45	3231	3234	1/3	time
# 45	3281	3286	23343	time
# 46	110	113	王醫師	name
# 46	200	204	一個禮拜	time
# 46	213	216	王醫師	name
# 46	384	394	0933625337	contact
# 47	130	134	九十公斤	med_exam
# 47	151	154	張醫師	name
# 47	666	670	一個禮拜	time
# 47	710	714	一個禮拜	time
# 47	716	718	五天	time
# 47	860	863	三年多	time
# 47	906	908	台積	location
# 47	969	972	下禮拜	time
# 48	95	97	今天	time
# 48	264	266	晚上	time
# 48	283	285	晚上	time
# 48	306	308	今天	time
# 48	370	372	昨天	time
# 48	649	652	140	med_exam
# 48	746	752	10月16號	time
# 48	754	756	小美	name
# 48	835	838	三個月	time
# 48	853	856	林醫師	name
# 48	933	935	兩天	time
# 48	1060	1062	晚上	time
# 48	1067	1069	晚上	time
# 48	1134	1136	晚上	time
# 48	1148	1150	八點	time
# 48	1185	1187	晚上	time
# 48	1193	1195	晚上	time
# 48	1207	1210	晚上多	time
# 48	1233	1236	140	med_exam
# 48	1596	1599	三個月	time
# 48	1692	1694	53	med_exam
# 48	1706	1708	53	med_exam
# 48	1709	1711	48	med_exam
# 48	1739	1740	亞	name
# 48	1750	1752	早上	time
# 48	1863	1871	吳小美66674	name
# 49	9	18	113993846	time
# 49	266	268	晚上	time
# 49	290	294	一個禮拜	time
# 49	301	305	一個禮拜	time
# 49	309	313	兩個禮拜	time
# 49	318	322	兩個禮拜	time
# 49	327	331	一個禮拜	time
# 49	333	336	這禮拜	time
# 49	788	790	晚上	time
# 49	793	795	今天	time
# 49	804	806	三點	time
# 49	885	887	晚上	time
# 49	930	932	晚上	time
# 49	977	979	晚上	time
# 49	1218	1220	晚上	time
# 49	1225	1227	晚上	time
# 49	1297	1299	晚上	time
# 49	1303	1305	晚上	time
# 50	41	44	林醫師	name
# 50	639	643	一個禮拜	time
# 50	729	734	1月15號	time
# 50	793	798	1月20號	time
# 50	802	804	一號	time
# 50	809	813	1月10	time
# 50	828	830	今天	time
# 50	832	834	今天	time
# 50	837	842	1月20號	time
# 50	1091	1096	1月26號	time
# 50	1969	1973	1月20	time
# 51	22	30	34666726	med_exam
# 51	118	121	許醫師	name
# 51	166	168	三天	time
# 51	218	221	14號	time
# 51	257	260	10號	time
# 51	283	289	10月15號	time
# 51	292	298	10月15號	time
# 51	319	325	11月18號	time
# 51	350	354	這張23	time
# 51	358	360	23	med_exam
# 51	441	446	12月7號	time
# 51	461	464	12月	time
# 51	469	474	12月16	time
# 51	479	484	12月16	time
# 51	523	525	明天	time
# 51	526	528	早上	time
# 51	587	591	兩個禮拜	time
# 51	596	600	兩個禮拜	time
# 51	626	631	12月7號	time
# 51	637	640	許醫師	name
# 51	643	648	12月7號	time
# 51	659	664	12月7號	time
# 51	669	674	12月7號	time
# 51	694	698	兩個禮拜	time
# 51	782	787	12月7號	time
# 51	797	801	兩個禮拜	time
# 51	832	837	12月7號	time
# 51	845	849	兩個禮拜	time
# 51	879	883	兩個禮拜	time
# 51	968	972	兩個禮拜	time
# 51	1005	1009	兩個禮拜	time
# 51	1115	1119	兩個禮拜	time
# 51	1136	1140	一個禮拜	time
# 51	1254	1256	18	med_exam
# 51	1270	1272	20	med_exam
# 51	1317	1320	這禮拜	time
# 51	1333	1337	一個禮拜	time
# 51	1346	1350	一個禮拜	time
# 51	1464	1467	許醫師	name
# 51	1507	1510	兩個月	time
# 51	1515	1518	兩個月	time
# 51	1627	1635	1.2000CC	time
# 51	1640	1646	1.2000	med_exam
# 51	1818	1822	10分鐘	time
# 52	3	7	這個禮拜	time
# 52	76	79	張醫師	name
# 52	88	91	張醫師	name
# 52	240	243	張醫師	name
# 52	311	315	下個禮拜	time
# 52	319	323	下個禮拜	time
# 52	634	637	下禮拜	time
# 53	50	53	陳醫師	name
# 53	54	57	陳家斌	name
# 53	471	474	李醫師	name
# 53	1038	1040	晚上	time
# 53	1068	1073	早上八點半	time
# 53	1084	1086	晚上	time
# 53	1089	1092	八點半	time
# 53	1097	1100	八點半	time
# 53	1114	1117	六點半	time
# 53	1188	1191	李醫師	name
# 53	1395	1398	237	time
# 53	1402	1408	10月19號	time
# 53	1413	1417	6月15	time
# 53	1418	1421	477	med_exam
# 54	94	98	這個禮拜	time
# 54	537	541	一百零四	med_exam
# 54	650	652	阿嬤	family
# 54	658	660	叔叔	family
# 55	113	118	這一、兩年	time
# 55	488	492	兩個禮拜	time
# 55	502	506	兩個禮拜	time
# 55	537	540	188	med_exam
# 55	558	561	十一萬	time
# 55	570	573	十五萬	med_exam
# 55	606	609	兩個月	time
# 55	689	691	九月	time
# 55	700	704	十二月底	time
# 55	709	714	十月十二號	time
# 55	720	725	十月十二號	time
# 55	738	744	十一月十二號	time
# 55	749	752	一個月	time
# 55	765	767	一號	time
# 55	779	782	二十天	time
# 55	805	809	四個禮拜	time
# 55	1197	1200	三個月	time
# 55	1227	1230	兩個月	time
# 55	1237	1240	兩個月	time
# 55	1247	1250	兩個月	time
# 55	1264	1267	四個月	time
# 55	1313	1316	兩個月	time
# 56	793	796	兩個月	time
# 56	811	815	三個禮拜	time
# 56	819	822	兩個月	time
# 56	829	832	兩個月	time
# 56	843	846	兩個月	time
# 56	1352	1356	二十一天	time
# 56	1360	1364	三個禮拜	time
# 56	1419	1425	十一月十九號	time
# 57	197	199	98	med_exam
# 57	441	443	兩年	time
# 57	452	454	兩年	time
# 57	488	492	3/11	med_exam
# 57	511	515	5/24	med_exam
# 57	525	529	4/23	med_exam
# 57	584	587	七月初	time
# 57	651	653	今天	time
# 57	662	664	今天	time
# 57	676	678	今天	time
# 57	680	683	黃醫師	name
# 57	720	722	七月	time
# 57	723	725	六月	time
# 57	726	728	五月	time
# 57	729	733	四月三號	time
# 57	744	748	四月三號	time
# 57	771	773	一年	time
# 57	787	789	一年	time
# 57	799	804	10月5號	time
# 58	23	25	10	med_exam
# 58	41	42	8	med_exam
# 58	216	219	兩個月	time
# 58	220	224	4月8號	time
# 58	226	230	這一個月	time
# 58	378	381	三個月	time
# 58	383	385	一年	time
# 58	393	396	兩個月	time
# 58	453	456	林醫師	name
# 58	710	713	林醫師	name
# 58	953	956	林醫師	name
# 58	1044	1046	林醫	name
# 58	1144	1147	黃醫師	name
# 58	1208	1211	三個月	time
# 58	1225	1228	三個月	time
# 58	1270	1276	三個月90天	time
# 58	1431	1434	三個月	time
# 58	1576	1579	三個月	time
# 58	1596	1599	三個月	time
# 58	1638	1640	半年	time
# 58	1684	1687	林醫師	name
# 58	1801	1804	三個月	time
# 59	122	124	兩天	time
# 59	129	131	晚上	time
# 59	134	136	七點	time
# 59	165	169	38.2	med_exam
# 59	256	258	晚上	time
# 59	633	636	這兩天	time
# 59	679	683	38.2	med_exam
# 59	684	688	37.9	med_exam
# 59	694	698	38.2	med_exam
# 59	702	705	379	med_exam
# 59	706	709	382	med_exam
# 59	859	861	早上	time
# 59	961	963	竹筍	location
# 59	967	969	竹筍	location
# 59	1035	1037	阿嬤	family
# 59	1052	1056	下個禮拜	time
# 59	1115	1117	早上	time
# 59	1119	1122	139	med_exam
# 59	1162	1164	阿嬤	family
# 59	1327	1329	早上	time
# 59	1472	1475	下禮拜	time
# 60	294	298	大東醫院	location
# 60	1013	1015	李黴	location
# 60	1131	1133	早上	time
# 60	1724	1727	上禮拜	time
# 60	1738	1741	上禮拜	time
# 60	2118	2121	10c	time
# 60	2159	2163	大東醫院	location
# 60	2198	2203	下下個禮拜	time
# 61	62	65	2.5	med_exam
# 61	142	146	四、五點	time
# 61	640	645	這兩個禮拜	time
# 61	1261	1263	今天	time
# 61	1331	1333	今天	time
# 61	1585	1587	一年	time
# 61	1782	1784	台灣	location
# 62	131	133	58	med_exam
# 62	170	173	175	med_exam
# 62	177	180	175	med_exam
# 62	187	190	175	med_exam
# 62	198	201	174	med_exam
# 62	220	223	8月底	time
# 62	504	506	我媽	family
# 62	815	817	5點	time
# 62	818	820	9點	time
# 62	827	829	晚上	time
# 62	835	837	下午	time
# 62	838	840	5點	time
# 62	844	846	下午	time
# 62	847	849	5點	time
# 62	862	864	晚上	time
# 62	889	891	早上	time
# 62	903	905	早上	time
# 62	926	928	下午	time
# 62	995	998	三個月	time
# 62	1009	1011	早上	time
# 62	1029	1030	爸	family
# 62	1071	1073	今天	time
# 62	1111	1113	早上	time
# 62	1173	1178	下個禮拜五	time
# 62	1222	1225	150	med_exam
# 62	1229	1232	150	med_exam
# 62	1252	1254	27	med_exam
# 62	1277	1279	昨天	time
# 62	1313	1316	500	money
# 62	1365	1368	500	money
# 62	1454	1458	150塊	money
# 62	1768	1770	哥哥	family
# 62	1894	1899	10/15	time
# 62	1928	1932	3452	time
# 63	9	16	4526780	med_exam
# 63	19	21	今天	time
# 63	88	90	今天	time
# 63	158	161	138	med_exam
# 63	171	173	今天	time
# 63	173	176	7．9	med_exam
# 63	185	188	130	med_exam
# 63	189	191	10	med_exam
# 63	205	208	7．9	med_exam
# 63	236	241	14600	med_exam
# 63	253	257	4900	med_exam
# 63	268	272	4900	med_exam
# 63	358	362	1．44	med_exam
# 63	486	488	早上	time
# 63	490	492	晚上	time
# 63	516	520	兩個禮拜	time
# 63	540	544	兩個禮拜	time
# 63	615	617	晚上	time
# 63	687	693	早上兩個晚上	time
# 63	698	701	28天	time
# 63	1004	1008	1200	time
# 63	1012	1016	1200	time
# 63	1021	1025	1200	time
# 63	1026	1030	1500	money
# 63	1038	1042	2100	time
# 63	1058	1062	2100	time
# 63	1233	1235	今天	time
# 63	1269	1273	兩個禮拜	time
# 64	3	5	阿明	name
# 64	12	14	今天	time
# 64	35	39	900多	money
# 64	715	717	今年	time
# 65	113	115	今天	time
# 65	262	266	八月七號	time
# 65	290	293	九十二	med_exam
# 65	294	299	一百三十一	med_exam
# 65	327	331	八月七號	time
# 65	339	343	八月七號	time
# 65	788	792	兩個禮拜	time
# 65	1421	1423	一天	time
# 65	1432	1435	三百三	time
# 65	1444	1446	美國	location
# 65	1453	1455	德國	location
# 65	1476	1479	七百二	med_exam
# 65	1675	1677	美國	location
# 65	1742	1745	涂醫師	name
# 65	1750	1753	七百二	med_exam
# 65	1792	1794	下午	time
# 65	2114	2119	七百二一天	time
# 65	2301	2311	F178290737	ID
# 66	3	5	小王	name
# 66	6	10	這個禮拜	time
# 66	35	37	昨天	time
# 66	73	75	早上	time
# 66	91	93	中午	time
# 66	180	184	這個禮拜	time
# 66	404	406	爸爸	family
# 66	427	429	今天	time
# 66	463	465	今天	time
# 66	516	518	今天	time
# 66	579	581	今天	time
# 66	586	588	今天	time
# 66	713	716	施德霖	location
# 66	786	789	上禮拜	time
# 66	816	820	台中醫院	location
# 67	21	24	禮拜一	time
# 67	25	29	晚上九點	time
# 67	80	83	禮拜一	time
# 67	84	86	晚上	time
# 67	91	93	今天	time
# 67	94	97	禮拜三	time
# 67	103	105	今天	time
# 67	106	109	禮拜一	time
# 67	110	112	早上	time
# 67	121	126	二十四小時	time
# 67	161	163	昨天	time
# 67	224	226	今天	time
# 67	227	229	早上	time
# 67	372	374	昨天	time
# 67	378	380	昨天	time
# 67	1122	1124	今天	time
# 67	1168	1170	明天	time
# 67	1195	1198	三四五	time
# 67	1215	1217	六日	time
# 67	1224	1226	六日	time
# 67	1235	1237	六日	time
# 67	1248	1250	六日	time
# 67	1300	1302	六日	time
# 67	1466	1468	禮拜	time
# 67	1472	1477	禮拜一早上	time
# 67	1487	1492	二十四小時	time
# 67	1531	1533	早上	time
# 67	1644	1646	昨天	time
# 67	1647	1649	晚上	time
# 67	1651	1654	五六點	time
# 67	1699	1701	早上	time
# 67	1722	1724	早上	time
# 67	1818	1821	禮拜五	time
# 67	1877	1880	下禮拜	time
# 67	1889	1892	禮拜五	time
# 67	1893	1896	禮拜五	time
# 67	1906	1908	早上	time
# 67	1914	1917	禮拜五	time
# 67	1918	1920	早上	time
# 67	2006	2008	今天	time
# 67	2274	2277	四個月	time
# 67	2434	2437	禮拜五	time
# 67	2474	2477	禮拜五	time
# 67	2552	2555	禮拜四	time
# 67	2556	2559	禮拜五	time
# 67	2568	2571	三、四	time
# 67	2576	2579	三、四	time
# 67	2584	2587	三、四	time
# 67	2600	2603	禮拜五	time
# 67	2645	2647	六日	time
# 67	2738	2740	昨天	time
# 67	2768	2770	中午	time
# 67	2773	2777	十二點多	time
# 67	2807	2810	禮拜一	time
# 67	2839	2841	八月	time
# 67	2842	2844	今天	time
# 67	2845	2848	十八日	time
# 67	2903	2907	37.3	med_exam
# 67	2913	2917	37.3	med_exam
# 67	2923	2927	37.3	med_exam
# 67	2928	2932	37.4	med_exam
# 67	2962	2964	早上	time
# 67	3094	3096	七天	time
# 67	3106	3108	七天	time
# 67	3221	3227	兩百二十八塊	money
# 67	3242	3244	十塊	money
# 67	3251	3255	四個禮拜	time
# 68	27	29	昨天	time
# 68	57	59	今天	time
# 68	78	80	今天	time
# 68	81	83	今天	time
# 68	410	414	一個禮拜	time
# 68	436	439	禮拜三	time
# 68	443	447	兩個禮拜	time
# 68	452	457	上個禮拜一	time
# 68	470	473	禮拜三	time
# 68	486	490	兩個禮拜	time
# 68	496	500	兩個禮拜	time
# 68	511	514	禮拜三	time
# 68	543	544	二	time
# 68	546	550	二三四五	time
# 68	552	554	四天	time
# 68	670	676	一個禮拜六日	time
# 68	735	738	許醫師	name
# 68	783	786	禮拜三	time
# 68	800	803	禮拜三	time
# 68	861	864	禮拜三	time
# 68	874	876	今天	time
# 68	881	884	禮拜三	time
# 68	901	904	禮拜三	time
# 68	916	919	禮拜三	time
# 68	929	932	禮拜三	time
# 68	937	940	禮拜一	time
# 68	943	945	昨天	time
# 68	1113	1116	許醫師	name
# 68	1125	1127	15	time
# 68	1128	1130	16	time
# 68	1144	1146	16	time
# 68	1150	1152	15	time
# 68	1153	1155	16	time
# 68	1157	1160	禮拜三	time
# 68	1171	1174	禮拜三	time
# 68	1203	1205	今天	time
# 68	1208	1211	禮拜三	time
# 68	1274	1276	今天	time
# 68	1277	1279	今天	time
# 68	1284	1286	今天	time
# 68	1304	1306	今天	time
# 68	1327	1330	許醫師	name
# 68	1353	1355	台大	location
# 68	1393	1396	王醫師	name
# 68	2173	2176	禮拜三	time
# 69	469	472	禮拜幾	time
# 69	482	484	今天	time
# 69	494	496	禮拜	time
# 69	500	502	禮拜	time
# 69	507	509	上上	time
# 69	514	516	七月	time
# 69	533	535	七夕	time
# 69	553	555	爸爸	family
# 69	682	686	兩個禮拜	time
# 69	690	694	兩個禮拜	time
# 69	698	702	兩個禮拜	time
# 69	984	987	林醫師	name
# 70	4	7	王老師	name
# 70	49	52	414	med_exam
# 70	53	56	356	med_exam
# 70	60	62	26	time
# 70	122	124	ｒｅ	location
# 70	143	147	ｒｕｐｅ	name
# 70	150	153	ｐｅｓ	med_exam
# 70	154	157	ｒｕ．	med_exam
# 70	536	540	一個禮拜	time
# 70	630	633	吳醫師	name
# 70	655	657	兩份	time
# 70	734	737	一個月	time
# 70	980	984	1300	med_exam
# 70	996	1000	1300	money
# 70	1288	1292	1300	money
# 70	1318	1322	1300	money
# 70	1432	1436	一個禮拜	time
# 70	1444	1446	5天	time
# 70	1607	1610	王老師	name
# 70	1627	1629	2張	time
# 70	1693	1695	7天	time
# 70	1704	1706	5天	time
# 70	1771	1773	7月	time
# 70	1809	1814	7月10號	time
# 70	1858	1862	9點11	time
# 70	1864	1870	13點16分	med_exam
# 70	1893	1898	7月16號	time
# 70	1899	1904	7月16號	time
# 70	1923	1928	10點55	med_exam
# 70	1932	1934	晚上	time
# 70	1958	1960	7月	time
# 70	1963	1968	7月23號	time
# 70	1971	1976	7月30號	time
# 70	1977	1981	8月3號	time
# 70	1987	1989	3號	time
# 70	2027	2029	兩張	time
# 71	4	8	這個禮拜	time
# 71	12	17	這個禮拜前	time
# 71	39	41	前天	time
# 71	464	468	這個禮拜	time
# 71	505	508	上禮拜	time
# 71	518	521	上禮拜	time
# 71	938	940	泰寧	location
# 71	1034	1036	晚上	time
# 71	1041	1043	晚上	time
# 71	1092	1096	下下禮拜	time
# 71	1204	1208	下下禮拜	time
# 72	32	35	禮拜三	time
# 72	56	59	禮拜四	time
# 72	105	108	這幾天	time
# 72	127	129	昨天	time
# 72	144	148	昨天晚上	time
# 72	162	167	37度點2	med_exam
# 72	185	188	三點半	time
# 72	353	357	今天早上	time
# 72	431	436	4.9公分	med_exam
# 72	568	570	今天	time
# 72	585	587	三點	time
# 72	618	622	27.3	med_exam
# 72	624	626	今天	time
# 72	627	630	2.6	med_exam
# 72	634	637	2.6	med_exam
# 72	641	644	2.6	med_exam
# 72	674	678	2100	time
# 72	680	684	2900	med_exam
# 72	768	770	明明	name
# 72	921	925	兩個禮拜	time
# 72	989	993	一個禮拜	time
# 72	1010	1012	兩週	time
# 72	1019	1021	兩週	time
# 72	1063	1065	早上	time
# 72	1068	1070	晚上	time
# 72	1091	1095	兩個禮拜	time
# 72	1109	1111	早上	time
# 72	1114	1116	晚上	time
# 72	1119	1121	一天	time
# 72	1136	1140	兩個禮拜	time
# 72	1197	1200	十四天	time
# 72	1217	1219	七天	time
# 72	1240	1242	七天	time
# 72	1298	1303	7月24號	time
# 72	1326	1328	今天	time
# 73	18	22	這個禮拜	time
# 73	29	33	這禮拜一	time
# 73	43	46	禮拜四	time
# 73	51	54	禮拜四	time
# 73	70	75	7月20號	time
# 73	92	95	889	med_exam
# 73	291	294	2．0	med_exam
# 73	651	654	下個月	time
# 73	718	720	去年	time
# 73	1000	1002	今天	time
# 73	1368	1370	早上	time
# 73	1375	1377	早上	time
# 73	1384	1386	早上	time
# 73	1390	1392	早上	time
# 73	1408	1410	晚上	time
# 73	1414	1416	早上	time
# 73	1464	1466	晚上	time
# 73	1937	1939	晚上	time
# 74	5	9	這個禮拜	time
# 74	109	113	這個禮拜	time
# 74	116	118	五天	time
# 74	567	569	晚上	time
# 74	592	594	晚上	time
# 74	603	605	晚上	time
# 74	978	982	下下禮拜	time
# 75	486	488	今天	time
# 75	511	513	今天	time
# 75	561	564	4.5	med_exam
# 75	568	571	4.5	med_exam
# 75	680	683	435	med_exam
# 75	687	690	435	med_exam
# 75	723	726	4.5	med_exam
# 75	852	856	1200	money
# 75	864	868	1200	time
# 75	979	983	2000	money
# 75	1266	1270	一個禮拜	time
# 75	1272	1276	下下禮拜	time
# 75	1410	1413	1.1	med_exam
# 75	1431	1434	0.幾	med_exam
# 75	1439	1442	0.幾	med_exam
# 75	1450	1453	1.1	med_exam
# 75	1457	1460	1.1	med_exam
# 75	1573	1577	下下禮拜	time
# 75	1580	1582	今天	time
# 76	7	10	林醫師	name
# 76	134	137	林醫師	name
# 76	214	216	昨天	time
# 76	537	541	前一兩天	time
# 76	1083	1086	陳醫師	name
# 76	1154	1156	今天	time
# 76	1692	1695	林醫師	name
# 76	1850	1854	兩千多塊	money
# 76	2196	2199	林醫師	name
# 76	2500	2503	林醫師	name
# 76	2751	2754	林醫師	name
# 76	2965	2968	大醫院	location
# 76	2976	2980	義大醫院	location
# 76	3007	3010	張醫師	name
# 76	3113	3116	禮拜三	time
# 76	3134	3137	禮拜四	time
# 83	2954	2958	15早上	time
# 83	3028	3030	32	med_exam
# 83	3041	3043	32	med_exam
# 83	3159	3164	十二個小時	time
# 83	3182	3184	早上	time
# 83	3192	3194	晚上	time
# 83	3199	3201	八點	time
# 83	3286	3288	今天	time
# 83	3328	3333	禮拜六早上	time
# 83	3363	3368	禮拜六早上	time
# 83	3412	3417	禮拜六早上	time
# 83	3448	3451	禮拜六	time
# 83	3476	3479	禮拜六	time
# 83	3480	3482	晚上	time
# 83	3483	3486	禮拜天	time
# 83	3490	3493	禮拜天	time
# 83	3549	3553	五個時段	time
# 83	3557	3561	五個時段	time
# 83	3571	3575	今天晚上	time
# 83	3580	3584	今天下午	time
# 83	3588	3592	今天下午	time
# 83	3594	3598	明天早上	time
# 83	3607	3611	明天下午	time
# 83	3615	3619	明天下午	time
# 83	3658	3661	禮拜天	time
# 83	3669	3673	禮拜一兩	time
# 83	3676	3679	禮拜二	time
# 83	3680	3682	早上	time
# 83	3729	3731	八點	time
# 83	3738	3742	下午五點	time
# 83	3752	3755	四點多	time
# 83	3793	3795	晚上	time
# 83	3815	3817	下午	time
# 83	3839	3845	八、九個小時	time
# 83	4007	4009	四天	time
# 84	637	639	席夢	name
# 84	677	680	三十年	time
# 84	902	904	早上	time
# 84	1106	1108	美美	location
# 84	1267	1270	一個月	time
# 84	1504	1506	波斯	name
# 84	1596	1600	兩個禮拜	time
# 84	1729	1732	723	time
# 84	1734	1737	723	time
# 84	1740	1744	一個禮拜	time
# 84	1776	1778	今天	time
# 84	1797	1801	一個禮拜	time
# 84	1832	1835	下禮拜	time
# 84	1974	1976	早上	time
# 84	2024	2027	723	med_exam
# 84	2051	2054	723	time
# 84	2117	2119	6天	time
# 84	2141	2143	7天	time
# 85	38	40	12	med_exam
# 85	169	171	22	med_exam
# 85	175	178	1.8	med_exam
# 85	572	575	上個月	time
# 85	629	632	兩千五	money
# 85	642	645	三千八	time
# 85	668	673	上上個禮拜	time
# 85	677	682	上上個禮拜	time
# 85	687	689	今天	time
# 85	694	698	九月七號	time
# 85	703	705	今天	time
# 85	743	747	明天早上	time
# 85	824	831	這兩、三個禮拜	time
# 85	881	888	這一、兩個禮拜	time
# 85	890	892	昨天	time
# 85	899	906	今天清晨兩點半	time
# 85	994	997	二、四	time
# 85	1084	1091	這一、兩個禮拜	time
# 85	1102	1105	100	money
# 85	1151	1154	170	med_exam
# 85	1155	1158	180	med_exam
# 85	1204	1207	170	med_exam
# 85	1236	1239	170	time
# 85	1278	1281	170	med_exam
# 85	1313	1316	170	med_exam
# 85	1334	1337	190	med_exam
# 85	1354	1357	190	med_exam
# 85	1366	1369	170	med_exam
# 85	1572	1574	工地	profession
# 85	1828	1830	早上	time
# 85	2035	2037	半年	time
# 85	2038	2040	一年	time
# 85	2209	2213	五、六年	time
# 85	2343	2345	九點	time
# 85	2367	2369	兩點	time
# 85	2370	2372	三點	time
# 85	2421	2425	早上六點	time
# 85	2566	2571	一、兩個月	time
# 85	2996	2999	王醫師	name
# 85	3083	3087	一個禮拜	time
# 85	3088	3092	兩個禮拜	time
# 85	3105	3109	一個禮拜	time
# 85	3179	3182	下禮拜	time
# 86	518	522	下個禮拜	time
# 86	608	611	下禮拜	time
# 87	249	253	一個禮拜	time
# 87	255	259	三個禮拜	time
# 87	276	280	9月4號	time
# 87	294	296	明年	time
# 87	316	318	年底	time
# 87	328	332	11月初	time
# 87	337	341	11月初	time
# 87	345	350	11月9號	time
# 87	356	360	下個禮拜	time
# 87	364	367	11月	time
# 88	45	48	吳老師	name
# 88	69	73	0．80	med_exam
# 88	104	107	90分	time
# 88	261	263	14	med_exam
# 88	273	276	200	med_exam
# 88	296	298	54	med_exam
# 88	489	492	130	med_exam
# 88	649	652	150	med_exam
# 88	696	698	80	med_exam
# 88	717	720	126	time
# 88	746	750	5601	med_exam
# 88	767	771	16．4	med_exam
# 88	1511	1513	半年	time
# 88	1518	1520	半年	time
# 88	1574	1576	一年	time
# 88	1628	1630	半年	time
# 88	1734	1736	1年	time
# 88	1775	1777	一年	time
# 88	1823	1825	明年	time
# 88	1865	1868	50歲	time
# 88	1977	1981	7月5號	time
# 88	1988	1991	2個月	time
# 88	1999	2001	兩年	time
# 88	2009	2011	兩年	time
# 89	3	6	王阿明	name
# 89	9	14	78392	ID
# 89	27	32	七月十五號	time
# 89	38	43	七月十五號	time
# 89	47	53	禮拜五他早上	time
# 89	300	302	今天	time
# 89	359	361	九月	time
# 89	373	375	今天	time
# 89	395	399	一個禮拜	time
# 89	519	521	晚上	time
# 89	524	526	晚上	time
# 89	536	538	晚上	time
# 89	544	546	晚上	time
# 89	614	616	早上	time
# 89	662	664	早上	time
# 89	921	923	今天	time
# 89	1035	1037	昨天	time
# 90	110	112	晚上	time
# 90	421	425	37.2	med_exam
# 90	581	583	晚上	time
# 90	613	615	說夢	name
# 90	622	624	晚上	time
# 90	634	636	講夢	name
# 90	762	764	晚上	time
# 90	772	774	晚上	time
# 90	909	911	晚上	time
# 90	982	984	晚上	time
# 90	1187	1191	10.9	med_exam
# 90	1206	1210	五月十號	time
# 90	1220	1224	四個多月	time
# 90	1229	1233	四個多月	time
# 90	1235	1238	五個月	time
# 90	1300	1303	六個月	time
# 90	1435	1439	四個禮拜	time
# 90	1526	1535	223640298	time
# 91	4	13	184058370	med_exam
# 91	273	275	早上	time
# 91	365	368	110	med_exam
# 91	372	375	110	med_exam
# 91	379	382	110	med_exam
# 91	520	523	0.5	med_exam
# 91	718	722	兩天三天	time
# 91	732	734	早上	time
# 91	750	753	禮拜三	time
# 91	793	794	十	time
# 91	796	802	11月25號	time
# 91	811	814	11月	time
# 91	819	825	11月25號	time
# 91	829	834	11月25	time
# 91	839	842	禮拜三	time
# 91	944	947	林醫師	name
# 91	1038	1042	2015	time
# 91	1046	1051	2015年	time
# 91	1065	1069	2017	time
# 91	1070	1072	兩年	time
# 91	1078	1082	2017	time
# 92	44	48	一、二天	time
# 92	52	56	一、二天	time
# 92	184	188	一個禮拜	time
# 92	204	208	一個禮拜	time
# 92	627	629	今天	time
# 92	730	733	五個月	time
# 92	764	767	兩百六	money
# 92	773	778	六百八十二	time
# 92	783	788	六百八十二	time
# 92	803	806	兩個月	time
# 92	833	838	第二份七十	time
# 92	959	961	兩百	money
# 92	973	976	七十塊	money
# 92	981	987	第二份七十塊	time
# 92	1101	1104	四月份	time
# 92	1129	1132	五月份	time
# 92	1142	1144	五一	time
# 92	1145	1148	五一八	time
# 92	1161	1164	五一八	time
# 92	1178	1181	五一八	time
# 92	1192	1194	七月	time
# 92	1195	1197	六月	time
# 92	1208	1211	六月中	time
# 92	1222	1224	五月	time
# 92	1246	1249	六月中	time
# 92	1258	1261	六月中	time
# 92	1424	1433	148390275	time
# 92	1468	1470	一年	time
# 92	1706	1708	凱柔	time
# 92	1757	1761	兩個禮拜	time
# 92	1778	1780	明天	time
# 92	1799	1801	後天	time
# 92	1828	1833	七月十八號	time
# 93	396	402	五、六個禮拜	time
# 93	406	412	五、六個禮拜	time
# 93	650	653	四個月	time
# 93	699	701	今天	time
# 93	803	813	1287394675	time
# 94	410	412	早上	time
# 94	472	474	今天	time
# 94	719	721	昨天	time
# 94	748	752	一個禮拜	time
# 94	918	921	這兩天	time
# 94	932	934	早上	time
# 94	1179	1181	晚上	time
# 94	1327	1331	八十八歲	time
# 94	1366	1368	五年	time
# 94	1399	1401	五年	time
# 94	1423	1426	五十幾	med_exam
# 94	1428	1431	七十幾	med_exam
# 94	1435	1438	七十幾	med_exam
# 94	1529	1531	八十	med_exam
# 94	1541	1543	八十	med_exam
# 94	1548	1550	八十	med_exam
# 94	1553	1555	八十	med_exam
# 94	1559	1561	八十	med_exam
# 94	1562	1565	八十太	med_exam
# 94	1579	1582	下個月	time
# 94	1637	1641	九月三號	time
# 94	2227	2230	五個月	time
# 94	2270	2274	兩個禮拜	time
# 94	2288	2290	九月	time
# 94	2294	2298	九月三號	time
# 94	2385	2387	今年	time
# 95	435	439	一個禮拜	time
# 95	852	854	一天	time
# 95	1679	1683	兩個禮拜	time
# 95	1811	1815	一個禮拜	time
# 96	491	493	晚上	time
# 96	505	508	五十幾	med_exam
# 96	522	525	五十九	time
# 96	538	541	五十九	med_exam
# 96	810	813	一五二	med_exam
# 96	996	999	一百三	med_exam
# 96	1280	1282	公斤	med_exam
# 96	1288	1291	三公斤	med_exam
# 96	1310	1313	100	time
# 96	1314	1317	105	med_exam
# 96	1321	1324	105	med_exam
# 96	2033	2035	那上	time
# 97	431	434	林醫師	name
# 97	488	491	林醫師	name
# 97	532	535	林醫師	name
# 97	558	560	台大	location
# 97	600	602	榮總	location
# 97	718	721	林醫師	name
# 97	998	1001	林醫師	name
# 97	1067	1071	上個禮拜	time
# 97	1198	1200	半年	time
# 97	1206	1208	半年	time
# 97	1213	1215	半年	time
# 97	1300	1302	榮總	location
# 97	1305	1307	台大	location
# 97	1431	1434	林醫師	name
# 97	2118	2123	林恆生醫師	name
# 97	2217	2221	一個禮拜	time
# 97	2595	2600	下下個禮拜	time
# 97	2620	2623	林醫師	name
# 97	2633	2636	林醫師	name
# 98	251	254	一個月	time
# 98	376	379	第二張	time
# 98	406	408	四年	time
# 98	416	418	七年	time
# 98	573	576	兩個禮	time
# 98	579	583	兩個禮拜	time
# 98	649	653	6月16	time
# 98	676	679	到年底	time
# 98	700	703	張醫師	name
# 98	708	711	11月	time
# 98	722	724	5月	time
# 98	747	750	11月	time
# 98	763	764	張	name
# 98	830	832	小美	name
# 98	850	853	林老師	name
# 98	973	976	一個月	time
# 98	995	998	一個月	time
# 98	1013	1016	12月	time
# 98	1035	1037	昨天	time
# 98	1072	1074	五週	time
# 98	1089	1091	五週	time
# 99	4	7	林先生	name
# 99	117	120	仙道彰	location
# 99	336	339	林阿奇	name
# 99	461	466	仙道彰醫師	name
# 99	719	721	中午	time
# 99	768	770	中午	time
# 99	892	895	5公分	med_exam
# 99	900	903	5公分	med_exam
# 99	1087	1089	5點	time
# 99	1099	1101	今天	time
# 99	1335	1338	兩個月	time
# 99	1341	1344	三個月	time
# 99	1498	1501	林醫師	name
# 99	1819	1821	明年	time
# 99	1822	1824	明年	time
# 99	1834	1836	早上	time
# 99	1840	1842	兩天	time
# 99	1888	1891	三個月	time
# 100	3	5	昨天	time
# 100	38	40	昨天	time
# 100	55	59	0.72	med_exam
# 100	84	88	2600	money
# 100	126	127	七	money
# 100	128	131	兩千六	money
# 100	596	598	晚上	time
# 100	902	904	兩年	time
# 100	905	908	兩年多	time
# 100	916	918	早上	time
# 100	932	934	小雅	name
# 100	1516	1519	9點幾	med_exam
# 100	1520	1523	8點幾	med_exam
# 100	1536	1539	8點幾	med_exam
# 100	1795	1799	兩個禮拜	time
# 100	1803	1807	兩個禮拜	time
# 100	1956	1958	台大	location
# 100	1997	1999	台大	location
# 100	2119	2122	一個月	time
# 100	2124	2129	1.5公斤	med_exam
# 100	2167	2170	4公斤	med_exam
# 100	2174	2177	4公斤	med_exam
# 100	2243	2247	四個禮拜	time
# 101	223	226	28天	time
# 101	350	353	施德霖	location
# 101	365	368	施德霖	location
# 101	471	473	下午	time
# 101	498	502	四個禮拜	time
# 102	4	6	今天	time
# 102	26	29	五點多	time
# 102	46	49	五點多	time
# 102	151	153	85	med_exam
# 102	157	160	10萬	med_exam
# 102	164	167	100	med_exam
# 102	187	189	85	med_exam
# 102	214	217	上個月	time
# 102	247	249	80	med_exam
# 102	282	284	27	med_exam
# 102	322	324	80	med_exam
# 102	435	437	晚上	time
# 102	671	673	我媽	family
# 102	828	832	兩個禮拜	time
# 103	300	302	今天	time
# 103	303	305	今年	time
# 103	307	309	今天	time
# 103	634	643	137465537	med_exam
# 104	127	130	三個月	time
# 104	267	274	十一月二十五號	time
# 104	336	338	去年	time
# 104	381	383	台大	location
# 104	461	468	十一月二十五號	time
# 105	31	33	竹科	location
# 105	174	176	今天	time
# 105	415	417	早上	time
# 105	418	420	下午	time
# 105	426	428	晚上	time
# 105	433	435	晚上	time
# 105	446	448	晚上	time
# 105	465	467	早上	time
# 105	893	895	今天	time
# 106	124	129	上上個禮拜	time
# 106	332	335	王醫師	name
# 106	347	352	100公斤	med_exam
# 106	369	372	102	med_exam
# 106	454	456	8點	med_exam
# 106	462	464	竹科	location
# 106	466	470	11點半	med_exam
# 106	473	475	晚上	time
# 106	476	478	晚上	time
# 106	511	513	一天	time
# 106	538	540	早上	time
# 106	544	546	晚上	time
# 106	627	630	下禮拜	time
# 106	637	641	下個禮拜	time
# 106	690	695	83946	time
# 107	39	43	2500	med_exam
# 107	44	48	2900	med_exam
# 107	59	63	2800	med_exam
# 107	85	88	1.0	med_exam
# 107	93	96	1.0	med_exam
# 107	99	103	1.87	med_exam
# 107	122	126	2500	med_exam
# 107	175	179	一個禮拜	time
# 107	196	197	3	med_exam
# 107	216	220	40分鐘	time
# 107	329	332	6點半	time
# 107	333	335	7點	time
# 107	350	353	2點半	time
# 107	526	529	9點半	time
# 107	530	533	10點	time
# 107	541	543	1點	time
# 107	603	605	5點	time
# 107	606	608	6點	time
# 107	622	624	晚上	time
# 107	682	684	晚上	time
# 107	697	699	3點	time
# 107	765	767	3點	med_exam
# 107	768	771	1點半	med_exam
# 107	779	782	1點半	med_exam
# 107	793	795	4點	time
# 107	869	871	晚上	time
# 107	875	879	10點半	time
# 107	886	889	11點	time
# 107	1136	1139	9點半	time
# 107	1153	1157	10點多	time
# 107	1158	1162	10點多	time
# 107	1200	1204	早上6點	time
# 107	1221	1225	11點多	time
# 107	1226	1229	12點	time
# 107	1707	1712	10幾年前	time
# 107	1912	1915	250	med_exam
# 107	2010	2014	6.7年	med_exam
# 107	2067	2070	李醫師	name
# 107	2246	2249	李醫師	name
# 107	2278	2281	李醫師	name
# 107	2282	2285	李醫師	name
# 107	2357	2360	前半年	time
# 107	2395	2398	李醫師	name
# 107	2499	2502	李醫師	name
# 107	2503	2506	李醫師	name
# 107	2577	2580	李醫師	name
# 107	2581	2584	李醫師	name
# 107	2694	2697	3個月	time
# 107	2701	2704	3個月	time
# 107	2708	2711	7、8	time
# 107	2712	2713	9	time
# 107	2714	2715	7	time
# 107	2752	2755	3個月	time
# 107	2794	2798	4個禮拜	time
# 107	2839	2843	4個禮拜	time
# 107	2912	2914	今天	time
# 108	106	109	張醫師	name
# 108	192	195	張醫師	name
# 108	592	594	張醫	name
# 108	1295	1298	三、四	time
# 108	1370	1373	禮拜一	time
# 108	1466	1469	張醫師	name
# 108	1623	1625	明天	time
# 108	2158	2161	三、四	time
# 108	2164	2165	三	time
# 108	2166	2167	四	time
# 108	2171	2174	禮拜三	time
# 108	2175	2178	禮拜四	time
# 108	2179	2182	禮拜五	time
# 108	2195	2197	今天	time
# 108	2209	2211	三天	time
# 108	2221	2224	張醫師	name
# 108	2265	2268	張醫師	name
# 108	2284	2287	張醫師	name
# 108	2357	2361	下個禮拜	time
# 108	2369	2373	下個禮拜	time
# 108	2816	2819	張醫師	name
# 109	192	194	今天	time
# 109	203	205	晚上	time
# 109	255	258	張醫師	name
# 109	336	338	晚上	time
# 109	490	493	四十二	time
# 109	537	540	五十歲	time
# 109	545	546	林	name
# 109	752	755	兩個月	time
# 109	823	829	十一月十五號	time
# 109	834	839	十一月十五	time
# 109	1040	1044	一個禮拜	time
# 109	1311	1315	上個禮拜	time
# 109	1321	1325	上個禮拜	time
# 109	1442	1446	一個禮拜	time
# 110	3	8	七十八點五	med_exam
# 110	12	17	七十八點五	med_exam
# 110	21	26	七十八點二	med_exam
# 110	31	36	七十八點二	med_exam
# 110	81	83	95	med_exam
# 110	217	223	八月三十一號	time
# 110	235	240	五百二十二	med_exam
# 110	248	253	五百二十二	med_exam
# 110	286	289	四百一	time
# 110	350	352	半年	time
# 110	434	436	爸爸	family
# 110	437	439	媽媽	family
# 110	497	499	去年	time
# 110	500	502	年初	time
# 110	509	511	每年	time
# 110	559	561	今年	time
# 110	563	565	去年	time
# 110	611	615	今年年初	time
# 110	634	636	去年	time
# 110	641	643	今年	time
# 110	863	867	二比二三	time
# 110	901	904	四十六	time
# 110	905	907	二三	time
# 110	908	910	二三	time
# 110	1148	1151	四個月	time
# 110	1407	1409	貢寮	name
# 110	1433	1438	下下個禮拜	time
# 110	1461	1463	八里	name
# 110	1494	1497	兩個月	time
# 110	1520	1522	東區	location
# 110	1526	1528	東區	location
# 110	1529	1531	台北	location
# 110	1535	1537	東區	location
# 110	1552	1554	台北	location
# 110	1556	1558	東區	location
# 110	1625	1629	二月五號	time
# 110	1855	1857	台北	location
# 111	1628	1632	兩個禮拜	time
# 111	1646	1650	兩個禮拜	time
# 111	1681	1686	三個禮拜前	time
# 111	1822	1827	三個禮拜前	time
# 111	1868	1870	瑞斯	name
# 111	1920	1922	瑞斯	name
# 111	1936	1941	三個禮拜前	time
# 111	2127	2129	瑞斯	name
# 111	2174	2176	台灣	location
# 111	2191	2193	台灣	location
# 111	2239	2241	瑞斯	name
# 111	2246	2248	瑞斯	name
# 111	2330	2332	瑞斯	name
# 111	2352	2353	F	name
# 111	2449	2453	兩個禮拜	time
# 111	2747	2750	五十歲	time
# 111	2768	2771	五十歲	time
# 112	287	289	前天	time
# 112	311	313	前天	time
# 112	491	494	陳小姐	name
# 112	514	517	陳小姐	name
# 112	584	586	今天	time
# 112	810	812	三天	time
# 113	1192	1195	前幾天	time
# 113	1614	1615	泰	location
# 113	1623	1624	泰	location
# 113	1849	1852	三個月	time
# 114	26	28	今天	time
# 114	77	80	7月份	time
# 114	116	119	六個月	time
# 114	174	177	六個月	time
# 114	242	245	三個月	time
# 114	447	450	六個月	time
# 114	566	569	三個月	time
# 114	612	615	六個月	time
# 114	625	628	六個月	time
# 114	675	678	三個月	time
# 114	1320	1321	2	time
# 114	1364	1369	10月7號	time
# 114	1396	1398	晚上	time
# 114	1765	1767	七月	time
# 114	1930	1934	兩個禮拜	time
# 114	2023	2026	四個月	time
# 114	2096	2098	今天	time
# 114	2103	2107	6615	time
# 114	2271	2275	六千多塊	money
# 114	2412	2414	60	time
# 114	2416	2419	60年	time
# ...
# 122	909	913	7月17	time
# 122	914	916	8月	time
# 122	921	925	一個半月	time
# 122	946	951	7月17號	time
# 122	966	972	10月16號	time
# 122	973	979	10月16號	time
# 122	1009	1015	11月21號	time
# 122	1102	1108	10月17號	time
# 122	1371	1373	泰國	location
# 122	1387	1391	3500	money
# 122	1392	1393	4	money
# 122	1393	1396	500	money
# 122	1407	1410	一個月	time
# 122	1417	1420	00多	money
# 122	1440	1444	250塊	money
# 122	1461	1465	250塊	money
# 122	1486	1491	12500	money
# 122	1495	1499	3500	money
# 122	1500	1504	4500	money
# 122	1753	1758	12500	time
# 122	1777	1781	5000	money
# 122	1818	1825	12500多塊	money
# 123	4	6	今天	time
# 123	26	29	這個月	time
# 123	133	135	明年	time
# 123	344	347	這個月	time
# 124	4	7	這個月	time
# 124	165	168	二十四	time
# 124	211	214	上個月	time
# 124	226	228	五月	time
# 124	271	275	這一個月	time
# 124	339	343	一個禮拜	time
# 124	448	451	這個月	time
# 125	4	7	這個月	time
# 125	696	699	禮拜幾	time
# 125	708	711	禮拜六	time
# 125	754	757	禮拜天	time
# 125	761	764	禮拜一	time
# 125	803	806	禮拜六	time
# 125	813	816	禮拜天	time
# 125	845	848	禮拜二	time
# 126	214	216	今天	time
# 126	224	226	今天	time
# 126	234	236	今天	time
# 126	251	253	昨天	time
# 126	254	256	早上	time
# 126	275	279	5、6點	time
# 126	307	309	晚上	time
# 126	365	367	早上	time
# 126	371	373	晚上	time
# 126	389	394	這一個禮拜	time
# 126	398	400	早上	time
# 126	403	405	晚上	time
# 126	454	456	中午	time
# 126	744	752	14738047	med_exam
# 127	413	415	今天	time
# 127	422	426	下個禮拜	time
# 127	456	459	三個月	time
# 127	489	492	300	money
# 127	569	571	今天	time
# 127	601	603	今天	time
# 127	620	623	12號	time
# 127	709	713	line	contact
# 128	7	10	三個月	time
# 128	836	841	11月2號	time
# 128	844	846	今天	time
# 128	850	855	11月2號	time
# 128	889	894	11月2號	time
# 128	928	932	7846	med_exam
# 128	941	946	五百二十六	time
# 129	7	10	這個月	time
# 129	17	20	這個月	time
# 129	142	144	今天	time
# 129	251	253	69	med_exam
# 129	693	696	許醫師	name
# 129	778	781	下個月	time
# 129	1049	1052	許醫師	name
# 129	1859	1862	3年多	time
# 129	1886	1888	3年	time
# 129	1998	2001	211	time
# 129	2002	2005	211	time
# 130	109	112	這個月	time
# 130	328	331	這個月	time
# 130	362	364	5點	time
# 130	378	381	替代役	profession
# 130	793	796	一個月	time
# 130	820	822	今天	time
# 130	823	828	11月2號	time
# 130	834	838	今天晚上	time
# 130	838	843	今天禮拜二	time
# 130	849	852	11點	time
# 130	865	867	9點	time
# 130	878	880	9點	time
# 130	909	914	11月3號	time
# 130	915	917	9點	time
# 130	923	928	11月4號	time
# 130	929	931	9點	time
# 130	1112	1115	小周末	time
# 130	1171	1177	11月10號	time
# 130	1178	1180	9點	time
# 130	1187	1189	9號	time
# 130	1191	1193	9點	time
# 131	154	157	25號	time
# 131	165	168	25號	time
# 131	173	176	25號	time
# 131	200	203	25號	time
# 131	272	275	25號	time
# 131	305	308	25號	time
# 131	364	366	今天	time
# 131	389	392	210	time
# 131	419	422	107	money
# 131	476	479	107	time
# 131	569	574	11月5號	time
# 131	580	582	晚上	time
# 131	587	590	11點	time
# 131	607	609	晚上	time
# 131	617	620	11點	time
# 131	661	663	9點	time
# 131	719	724	11月6號	time
# 131	733	738	11月7號	time
# 131	739	741	晚上	time
# 131	827	829	9點	time
# 131	831	833	9點	time
# 131	890	892	今天	time
# 131	893	896	禮拜四	time
# 131	903	905	今天	time
# 131	915	917	明天	time
# 131	982	984	9點	time
# 131	993	995	晚上	time
# 131	1015	1021	11月11號	time
# 131	1028	1034	11月12號	time
# 131	1035	1037	9點	time
# 131	1103	1107	一個禮拜	time
# 131	1154	1158	line	contact
# 131	1212	1218	號73846	ID
# 132	4	7	這個月	time
# 132	103	105	三年	time
# 132	116	122	兩年多一點點	time
# 132	128	131	兩年多	time
# 132	274	277	這個月	time
# 132	1109	1111	今天	time
# 132	1125	1130	9月28號	time
# 132	1131	1137	10月12號	time
# 132	1163	1165	三天	time
# 132	1194	1196	晚上	time
# 132	1207	1209	8點	time
# 132	1213	1215	晚上	time
# 132	1275	1278	106	time
# 132	1420	1424	ＬＩＮＥ	contact
# 133	4	7	這個月	time
# 133	39	42	這個月	time
# 133	51	54	這個月	time
# 133	58	61	這個月	time
# 133	281	283	王先	name
# 133	749	753	3200	money
# 133	766	770	3200	money
# 133	785	790	5000多	money
# 133	792	797	6000塊	money
# 133	828	832	兩萬多塊	money
# 134	4	7	這個月	time
# 134	14	17	這個月	time
# 134	397	399	今天	time
# 134	447	449	明年	time
# 134	450	454	3月7號	time
# 134	477	481	下禮拜二	time
# 135	4	7	這個月	time
# 135	83	86	這個月	time
# 135	406	409	6月份	time
# 135	427	430	6月份	time
# 135	450	452	今天	time
# 135	459	461	今天	time
# 135	487	489	今天	time
# 135	536	539	吳醫師	name
# 135	878	880	泰國	location
# 135	971	974	兩千二	money
# 135	1000	1002	七千	money
# 135	1007	1009	七千	money
# 135	1019	1021	七千	med_exam
# 135	1277	1280	吳醫師	name
# 135	1373	1375	兩千	money
# 135	1377	1380	兩千五	money
# 136	28	32	這一個月	time
# 136	63	65	昨天	time
# 136	88	90	五點	time
# 136	183	186	這個月	time
# 136	207	210	這個月	time
# 136	322	325	劉醫師	name
# 136	379	381	今天	time
# 136	413	415	半年	time
# 136	614	618	下個禮拜	time
# 136	697	701	12月底	time
# 137	146	150	這禮拜前	time
# 137	155	157	早點	time
# 137	258	262	上個禮拜	time
# 137	263	267	11月底	time
# 137	287	289	台灣	location
# 137	295	297	台灣	location
# 137	371	375	上個禮拜	time
# 137	384	388	一月五號	time
# 137	481	483	今天	time
# 137	508	510	今天	time
# 137	603	607	這一個月	time
# 137	614	617	這個月	time
# 137	728	731	這個月	time
# 137	807	809	今天	time
# 137	900	902	醫師	name
# 137	915	917	兩天	time
# 137	1140	1142	今天	time
# 137	1287	1290	107	money
# 137	1399	1403	Line	contact
# 137	1446	1448	明年	time
# 137	1476	1478	今天	time
# 137	1566	1568	今天	time
# 137	1576	1578	今天	time
# 137	1593	1595	兩天	time
# 137	1703	1707	二十八天	time
# 137	1730	1733	晚兩天	time
# 137	1799	1803	今天晚上	time
# 137	1873	1876	這幾天	time
# 137	1900	1905	這一個禮拜	time
# 137	2057	2060	107	time
# 137	2061	2064	100	money
# 137	2070	2073	100	money
# 138	30	33	31題	med_exam
# 138	43	46	31題	med_exam
# 138	60	63	31題	med_exam
# 138	64	66	32	med_exam
# 138	91	94	五十幾	time
# 138	171	174	這個月	time
# 138	229	233	四個禮拜	time
# 138	1133	1138	12月7號	time
# 138	1151	1156	12月7號	time
# 138	1157	1160	22號	time
# 138	1232	1235	12月	time
# 138	1256	1261	12月7號	time
# 138	1444	1448	LINE	contact
# 138	1578	1580	7號	time
# 138	1593	1595	7號	time
# 138	1596	1599	22號	time
# 139	198	202	兩個禮拜	time
# 139	364	366	五月	time
# 139	435	437	高雄	location
# 139	438	440	台南	location
# 139	632	635	王醫師	name
# 140	141	145	一兩個月	time
# 140	283	287	兩個禮拜	time
# 140	306	308	新竹	location
# 140	326	328	新竹	location
# 140	402	404	今天	time
# 140	405	409	二十三號	time
# 140	410	412	七號	time
# 140	419	421	今天	time
# 140	466	468	小姐	name
# 140	538	541	上個月	time
# 140	561	563	小姐	name
# 140	579	581	30	money
# 140	902	905	一個月	time
# 140	919	923	一個禮拜	time
# 140	929	933	一個禮拜	time
# 140	947	950	兩個月	time
# 140	1082	1084	今年	time
# 140	1192	1194	四百	money
# 140	1207	1212	一萬三左右	money
# 140	1227	1230	一萬三	money
# 140	1322	1324	泰國	location
# 140	1369	1372	一千五	money
# 140	1716	1719	四年多	time
# 140	1732	1734	兩年	time
# 140	1766	1768	五年	time
# 140	1790	1793	17歲	time
# 140	1809	1812	17歲	time
# 140	1914	1917	王小陸	name
# 140	1918	1921	735	med_exam
# 141	138	141	一個月	time
# 141	162	165	一個月	time
# 141	908	910	今天	time
# 141	966	969	兩個月	time
# 141	1119	1122	11月	time
# 141	1123	1125	明年	time
# 141	1126	1128	3月	time
# 141	1159	1163	6700	money
# 141	1166	1170	6700	money
# 141	1171	1175	6500	money
# 141	2144	2145	爸	family
# 141	2387	2391	三個禮拜	time
# 141	2397	2401	三個禮拜	time
# 141	2410	2413	三個月	time
# 141	2415	2418	三個月	time
# 142	17	26	00382694張	time
# 142	38	41	5個月	time
# 142	269	272	三個月	time
# 142	326	329	六個月	time
# 142	456	461	EMAIL	contact
# 142	486	490	LINE	contact
# 142	1319	1323	兩個禮拜	time
# 142	1326	1330	一個禮拜	time
# 142	1332	1336	一個禮拜	time
# 142	1709	1711	今天	time
# 142	1872	1874	半年	time
# 142	1987	1989	今天	time
# 142	2025	2028	一個月	time
# 142	2625	2628	一個月	time
# 142	2658	2660	晚上	time
# 142	2664	2666	下午	time
# 142	2691	2694	一個月	time
# 143	24	26	八月	time
# 143	88	92	這三個月	time
# 143	305	309	8月9號	time
# 143	310	312	8月	time
# 143	449	452	星星點	time
# 143	460	463	星星點	time
# 143	492	495	兩個月	time
# 143	621	623	今天	time
# 143	639	641	八周	time
# 143	696	700	八個禮拜	time
# 143	710	714	八個禮拜	time
# 143	715	719	2月22	time
# 143	808	818	0927773645	time
# 144	69	71	昨天	time
# 144	72	74	前天	time
# 144	166	168	台中	location
# 144	186	188	台中	location
# 144	255	257	周末	time
# 144	275	279	這個周末	time
# 144	325	327	東區	location
# 144	2012	2014	今天	time
# 144	2096	2099	一個月	time
# 144	2263	2266	禮拜二	time
# 145	9	14	十二月三號	time
# 145	23	26	禮拜三	time
# 145	30	35	十二月五號	time
# 145	39	44	十二月五號	time
# 145	55	57	十月	time
# 145	65	68	十月底	time
# 145	79	81	四週	time
# 145	84	91	十一月二十三號	time
# 145	93	96	禮拜四	time
# 145	99	105	十一月二十三	time
# 145	143	148	一個禮拜四	time
# 145	158	161	禮拜三	time
# 145	165	171	十一月二十九	time
# 145	188	191	後一週	time
# 145	204	208	二十五號	time
# 145	249	252	禮拜三	time
# 145	263	265	一週	time
# 145	269	276	十一月二十五日	time
# 145	277	280	禮拜四	time
# 145	309	314	十二月四號	time
# 145	377	379	29	med_exam
# 145	380	382	29	time
# 145	550	552	台中	location
# 145	903	906	五六日	time
# 145	911	914	禮拜五	time
# 145	927	930	禮拜日	time
# 145	943	946	禮拜一	time
# 145	1178	1180	八點	time
# 145	1187	1190	禮拜六	time
# 145	1191	1194	禮拜天	time
# 145	1195	1197	八點	time
# 145	1222	1225	禮拜天	time
# 145	1226	1228	晚上	time
# 145	1247	1249	八點	time
# 145	1254	1258	兩個八點	time
# 145	1376	1379	禮拜六	time
# 145	1437	1439	兩天	time
# 145	1612	1616	一個禮拜	time
# 145	1669	1673	8932	time
# 146	3	5	小華	name
# 146	7	16	189370256	med_exam
# 146	46	49	十月底	time
# 146	67	69	上周	time
# 146	432	434	三天	time
# 146	968	971	星星還	time
# 146	1056	1060	第五個月	time
# 146	1075	1077	今天	time
# 146	1079	1082	下個月	time
# 146	1162	1164	半年	time
# 146	1179	1181	半年	time
# 146	1189	1191	今天	time
# 146	1196	1199	三個月	time
# 146	1210	1214	九百多塊	money
# 147	5	8	這個月	time
# 147	40	43	這個月	time
# 147	683	685	今天	time
# 147	700	702	今天	time
# 147	710	712	今天	time
# 147	804	807	一個月	time
# 147	850	854	一個禮拜	time
# 147	857	861	三個禮拜	time
# 147	871	876	一個禮拜多	time
# 147	925	928	下禮拜	time
# 147	929	933	下下禮拜	time
# 147	937	941	每個禮拜	time
# 147	1082	1084	禮拜	time
# 147	1085	1088	下禮拜	time
# 147	1091	1094	清明節	time
# 147	1110	1113	禮拜一	time
# 147	1572	1574	半年	time
# 147	1631	1633	半年	time
# 147	1637	1639	半年	time
# 147	1662	1664	今天	time
# 147	1670	1672	今天	time
# 147	1814	1818	三個禮拜	time
# 148	52	55	三個月	time
# 148	58	61	7月底	time
# 148	152	155	8月底	time
# 148	168	174	5、6、7月	time
# 148	701	703	今天	time
# 148	865	867	今天	time
# 149	171	174	一個月	time
# 149	377	380	三月初	time
# 149	387	390	七月底	time
# 149	394	397	三四五	time
# 149	414	417	五個月	time
# 149	423	426	三個月	time
# 149	1485	1489	這四個月	time
# 149	1559	1564	兩三個禮拜	time
# 149	1666	1668	今天	time
# 149	1932	1934	今天	time
# 149	1966	1968	四月	time
# 149	1976	1978	半年	time
# 149	2014	2016	今天	time
# 149	2021	2024	下禮拜	time
# 149	2046	2049	下禮拜	time
# 149	2059	2061	禮拜	time
# 149	2063	2066	禮拜一	time
# 149	2072	2075	禮拜一	time
# 149	2076	2078	早上	time
# 149	2082	2084	早上	time
# 149	2088	2091	禮拜一	time
# 149	2092	2094	早上	time
# 149	2095	2096	三	time
# 149	2097	2099	下午	time
# 149	2100	2101	四	time
# 149	2102	2104	早上	time
# 149	2105	2109	五的早上	time
# 149	2116	2119	禮拜一	time
# 149	2120	2122	早上	time
# 149	2134	2138	下禮拜一	time
# 149	2139	2143	十月七號	time
# 149	2147	2150	前一天	time
# 149	2161	2165	十月十號	time
# 149	2171	2174	國慶日	time
# 149	2182	2186	下禮拜二	time
# 149	2208	2212	這禮拜放	time
# 149	2213	2216	下禮拜	time
# 149	2218	2220	三天	time
# 149	2238	2241	這禮拜	time
# 149	2242	2244	四天	time
# 149	2245	2248	下禮拜	time
# 149	2249	2251	三天	time
# 149	2261	2265	下禮拜二	time
# 149	2276	2279	禮拜一	time
# 149	2288	2292	十月七號	time
# 150	85	87	兩天	time
# 150	90	92	小花	name
# 150	129	133	下個禮拜	time
# 150	191	193	今天	time
# 150	218	220	今天	time
# 150	378	384	10月20號	time
# 150	427	430	這個月	time
# 150	529	532	兩三顆	time
# 150	575	577	晚上	time
# 150	1531	1533	今天	time
# 150	1630	1633	這一年	time
# 150	1715	1717	明年	time
# 150	1760	1762	今年	time
# 150	1796	1798	明年	time
# 150	2183	2187	414塊	money
# 150	2329	2332	一個月	time
# 150	2354	2357	兩三次	time
# 150	2471	2474	前兩天	time
# 150	2781	2782	2	time
# 150	3002	3004	五點	time
# 150	3061	3064	一個月	time
# 150	3079	3082	一個月	time
# 150	3126	3129	這個月	time
# 150	3135	3138	五個月	time
# 150	3548	3553	一萬三左右	money
# 150	3606	3609	一萬三	money
# 150	3655	3659	一萬三大	money
# 150	3852	3856	1500	money
# 150	4568	4569	兩	time
# 150	4571	4574	兩三年	time
# 150	4681	4685	1500	money
# 150	4957	4961	四五個月	time
# 150	5200	5203	一兩天	time
# 150	5979	5983	10月中	time
# 150	6294	6296	明年	time
# 150	6302	6304	一月	time
# 150	6426	6429	13周	time
# 150	6439	6442	13周	time
# 150	6446	6449	13周	time
# 150	6463	6466	12周	time
# 150	6473	6478	1月10號	time
# 150	6482	6487	1月10號	time
# 150	6501	6503	今天	time
# 150	6506	6509	三個月	time
# 150	6577	6581	1月10	time
# 150	6590	6592	今年	time
# 150	6595	6597	跨年	time
# 150	6605	6609	1月1號	time
# 150	6610	6613	禮拜五	time
# 150	6619	6622	五六日	time
# 150	6629	6632	五六日	time
# 150	6654	6656	今天	time
# 150	6657	6660	星期四	time
# 150	6797	6800	五六日	time
# 150	6914	6916	泰國	location
# 150	6947	6949	泰國	location
# 150	7018	7020	泰國	location
# 150	7093	7095	早上	time
# 150	7183	7188	兩三個小時	time
# 150	7258	7260	今天	time
# 150	7419	7422	12點	time
# 150	7565	7570	83765	med_exam
# 151	52	55	這個月	time
# 151	106	109	這個月	time
# 151	344	346	今天	time
# 151	676	678	明年	time
# 151	748	750	明年	time
# 151	1015	1018	每個月	time
# 151	1167	1170	下個月	time
# 151	1228	1231	10月	time
# 151	1246	1249	10月	time
# 151	1274	1276	六周	time
# 151	1280	1282	六周	time
# 151	1286	1291	10月15	time
# 151	1304	1307	禮拜二	time
# 151	1308	1310	早上	time
# 151	1312	1314	今天	time
# 151	1397	1399	半年	time
# 152	334	337	這個月	time
# 152	345	348	這個月	time
# 152	407	410	下禮拜	time
# 152	529	531	明年	time
# 152	845	847	一百	money
# 152	859	862	一個月	time
# 152	866	869	五千多	money
# 152	958	961	七十塊	money
# 152	969	972	一千九	money
# 152	983	985	泰國	location
# 152	991	993	泰國	location
# 152	1316	1320	兩個禮拜	time
# 152	1327	1330	三個月	time
# 152	1338	1341	三個月	time
# 152	1345	1346	九	med_exam
# 152	1675	1678	下個月	time
# 152	1733	1738	一萬三左右	money
# 152	1780	1785	三四個禮拜	time
# 152	1876	1881	兩個禮拜內	time
# 152	1898	1903	兩個禮拜前	time
# 152	1916	1920	兩個禮拜	time
# 152	2256	2259	下個月	time
# 152	2312	2315	兩個月	time
# 152	2383	2386	下個月	time
# 152	2566	2568	今天	time
# 152	2579	2583	九月三十	time
# 152	2630	2632	今天	time
# 152	3009	3015	九月二十幾號	time
# 152	3243	3246	兩個月	time
# 152	3329	3332	三十號	time
# 152	3532	3535	這個月	time
# 152	3638	3643	二十四小時	time
# 152	3714	3716	八點	time
# 152	3731	3733	七點	time
# 152	3744	3746	八點	time
# 152	3764	3766	八點	time
# 152	3909	3911	早上	time
# 152	3913	3915	五點	time
# 153	3	6	這個月	time
# 153	130	132	今天	time
# 153	150	154	第六個月	time
# 153	163	166	下個月	time
# 153	175	177	半年	time
# 153	265	267	今天	time
# 153	275	277	今天	time
# 153	285	287	今天	time
# 153	311	313	今天	time
# 153	357	360	這半年	time
# 153	387	390	六個月	time
# 153	1027	1032	兩個禮拜內	time
# 153	1113	1116	一個月	time
# 153	1120	1123	一個月	time
# 153	1338	1343	兩、三個月	time
# 153	1436	1439	一萬五	money
# 153	1443	1446	521	money
# 153	1484	1487	170	money
# 153	1587	1591	680塊	money
# 153	1599	1605	600多一點	money
# 153	1654	1656	泰國	location
# 153	1662	1664	泰國	location
# 153	1668	1671	一個月	time
# 153	1675	1679	1600	money
# 153	1690	1693	60塊	money
# 153	1705	1708	1/3	time
# 153	1720	1723	521	med_exam
# 153	1726	1729	1/3	time
# 153	1730	1733	1/3	med_exam
# 153	1842	1844	台灣	location
# 153	2017	2019	泰國	location
# 153	2321	2323	半年	time
# 153	2605	2607	明年	time
# 153	2693	2696	三個月	time
# 154	3	6	這個月	time
# 154	19	22	這個月	time
# 154	132	135	這個月	time
# 154	157	159	學東	location
# 154	252	256	一個半月	time
# 154	668	670	今天	time
# 154	1020	1023	前一天	time
# 154	1169	1171	7點	time
# 154	1178	1182	晚上7點	time
# 154	1699	1702	這個月	time
# 154	2129	2132	5月底	time
# 154	2140	2143	8月底	time
# 154	2153	2159	兩﹑三個禮拜	time
# 155	4	7	這個月	time
# 155	48	51	這個月	time
# 155	85	87	今天	time
# 155	107	109	今天	time
# 155	113	116	下禮拜	time
# 155	145	148	這個月	time
# 155	199	203	一個禮拜	time
# 155	404	406	今年	time
# 155	594	596	明年	time
# 155	733	736	這一年	time
# 155	1000	1002	台灣	location
# 155	1021	1023	台灣	location
# 155	1092	1095	510	money
# 155	1105	1108	一萬五	money
# 155	1171	1174	一萬五	money
# 155	1203	1207	五千多塊	money
# 155	1260	1263	一萬五	money
# 155	1376	1378	泰國	location
# 155	1382	1384	泰國	location
# 155	1395	1397	泰國	location
# 155	1405	1407	泰國	location
# 155	1629	1632	一個月	time
# 155	1634	1638	1800	money
# 155	1647	1651	1800	money
# 155	1693	1697	一個多月	time
# 155	1780	1785	兩個禮拜內	time
# 155	2354	2357	王龍龍	name
# 155	2437	2440	三個月	time
# 155	2549	2553	ＬＩＮＥ	contact
# 156	1003	1005	兩天	time
# 156	1625	1627	台灣	location
# 156	1812	1814	今年	time
# 156	2196	2199	今年公	time
# 156	2239	2241	今年	time
# 156	2244	2246	台灣	location
# 156	2479	2481	台灣	location
# 156	2600	2602	今年	time
# 156	2770	2772	今年	time
# 156	2961	2963	今年	time
# 156	3013	3017	今年醫院	time
# 156	3210	3212	台北	location
# 156	3273	3277	5632	med_exam
# 157	292	295	這個月	time
# 157	449	453	第二個月	time
# 157	469	473	第二個月	time
# 157	695	698	這禮拜	time
# 157	900	902	一年	time
# 157	1298	1304	五百五十二塊	money
# 157	1371	1374	一萬六	money
# 157	1381	1384	一萬六	money
# 157	1403	1406	一萬六	money
# 157	1424	1429	一百八十塊	money
# 157	1480	1485	五千五百塊	money
# 157	1524	1527	七百塊	money
# 157	1544	1547	七百塊	money
# 157	1589	1592	五千塊	money
# 157	1624	1626	台灣	location
# 157	1645	1647	台灣	location
# 157	1675	1677	台灣	location
# 157	1735	1737	泰國	location
# 157	1751	1753	泰國	location
# 157	1794	1796	泰國	location
# 157	1894	1897	一千八	money
# 157	1955	1958	一千八	money
# 157	1959	1962	五千五	money
# 157	2177	2179	泰國	location
# 157	3290	3295	HUANG	contact
# 157	3487	3489	今天	time
# 157	3495	3497	今天	time
# 157	3597	3599	四週	time
# 157	3609	3611	高雄	location
# 157	3619	3621	四週	time
# 157	3627	3629	九月	time
# 157	3633	3635	十四	time
# 157	3643	3647	九月十四	time
# 157	3648	3651	禮拜幾	time
# 157	3658	3663	禮拜三早上	time
# 157	3672	3677	禮拜二早上	time
# 157	3689	3692	禮拜一	time
# 157	3703	3708	禮拜一下午	time
# 157	3722	3726	這個禮拜	time
# 157	3733	3737	這禮拜一	time
# 157	3753	3756	禮拜五	time
# 157	3777	3781	九月十號	time
# 157	3785	3789	九月十號	time
# 157	3822	3825	禮拜五	time
# 158	91	94	這個月	time
# 158	127	130	這個月	time
# 158	193	197	四個禮拜	time
# 158	335	337	今天	time
# 158	431	435	二十二十	med_exam
# 158	466	469	五十幾	med_exam
# 158	1082	1086	第三個月	time
# 158	1111	1116	一個下個月	time
# 158	1143	1145	今天	time
# 158	1381	1390	124699678	time
# 158	1489	1491	明年	time
